# %%
import re
import json

# %%
# Importing the dataset
lines = open('movie_lines.txt', encoding = 'utf-8', errors = 'ignore').read().split('\n')
conversations = open('movie_conversations.txt', encoding = 'utf-8', errors = 'ignore').read().split('\n')

# %%
# Creating a dictionary that maps each line and its id
id2line = {}
for line in lines:
    _line = line.split(' +++$+++ ')
    if len(_line) == 5:
        id2line[_line[0]] = _line[4]

# %%
# Creating a list of all of the conversations
conversations_ids = []
for conversation in conversations[:-1]:
    _conversation = conversation.split(' +++$+++ ')[-1][1:-1].replace("'", "").replace(" ", "")
    conversations_ids.append(_conversation.split(','))

# %%
# Getting separately the questions and the answers
questions = []
answers = []
for conversation in conversations_ids:
    for i in range(len(conversation) - 1):
        questions.append(id2line[conversation[i]])
        answers.append(id2line[conversation[i+1]])

# %%
# Doing a first cleaning of the texts
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    return text

# %%
# Cleaning the questions
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))

# %%
# Cleaning the answers
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %%
# Filtering out the questions and answers that are too short or too long
short_questions = []
short_answers = []
i = 0
for question in clean_questions:
    if 2 <= len(question.split()) <= 25:
        short_questions.append(question)
        short_answers.append(clean_answers[i])
    i += 1
clean_questions = []
clean_answers = []
i = 0
for answer in short_answers:
    if 2 <= len(answer.split()) <= 25:
        clean_answers.append(answer)
        clean_questions.append(short_questions[i])
    i += 1

# %%
clean_answers
# Out:
# ['well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  "okay then how 'bout we try out some french cuisine  saturday  night",
#  'forget it',
#  'seems like she could get a date easy enough',
#  'that is a shame',
#  'let me see what i can do',
#  'right  see  you are ready for the quiz',
#  'forget french',
#  "well there's someone i think might be ",
#  'i counted on you to help my cause you and that thug are obviously failing are not we ever going on our date',
#  'you are sweet',
#  "eber's deep conditioner every two days and i never ever use a blowdryer without the diffuser attachment",
#  'i really really really wanna go but i ca not  not unless my sister goes',
#  "i am workin' on it but she does not seem to be goin' for him",
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'who knows  all i have ever heard her say is that she would dip before dating a guy that smokes',
#  'i believe we share an art instructor',
#  'i was',
#  "you never wanted to go out with 'me did you",
#  'then that is all you had to say',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'thank god  if i had to hear one more story about your coiffure',
#  'what good stuff',
#  'the real you',
#  'like my fear of wearing pastels',
#  'i hope so',
#  'they do not',
#  'combination  i do not know  i thought he would be different  more of a gentleman',
#  "i do not have to be home 'til two",
#  'i did',
#  "it's a gay cruise line but i will be like wearing a uniform and stuff",
#  'hi joey',
#  "you are concentrating awfully hard considering it's gym class",
#  "you know the deal  i can ' t go if kat does not go ",
#  'nowhere hi daddy',
#  'can you at least start wearing a bra',
#  'it means that gigglepuss is playing at club skunk and we are going',
#  'i think you are a freak  i think you do this to torture me  and i think you suck',
#  'what is normal',
#  "bogey lowenstein's party is normal but you are too busy listening to bitches who need prozac to know that",
#  'at least i am not a clouted fen sucked hedgepig',
#  "it's shakespeare  maybe you have heard of him",
#  'can we go now',
#  'i really do not think i need any social advice from you right now',
#  'like you care',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s ",
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'as in',
#  'you did what',
#  'just once  afterwards i told him i did not want to anymore  i was not ready he got pissed  then he broke up with me',
#  'i wanted to let you make up your own mind about him',
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him just keep me locked away in the dark so i ca not experience anything for myself',
#  'not all experiences are good bianca you ca not always trust the people you want to',
#  'i guess i will never know will i',
#  'so did you',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'no i just wanted',
#  "it's just you",
#  'no you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  "but it's not fair  she is a mutant daddy",
#  'exactly my point',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  "it's just a party daddy but i knew you would forbid me to go since gloria steinem over there is not going ",
#  "if kat's not going you are not going",
#  "it's just a party daddy",
#  'daddy no',
#  'just for a minute',
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'fine  i see that i am a prisoner in my own house  i am not a daughter i am a possession',
#  "i have a date daddy  and he ' s not a captain of oppression like some men we know",
#  'did not have you pegged for a gigglepuss fan  are not they a little too preteen bellybutton ring for you',
#  'fan of a fan  you see a couple of minors come in',
#  "just sent 'em through",
#  'so they tell me',
#  "c'mon  i am supposed to give you the tour",
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'how many people were in your old school',
#  'how many people go here',
#  'couple thousand most of them evil',
#  'yeah but these guys have never seen a horse  they just jack off to clint eastwood',
#  'you burn you pine you perish',
#  'who is she',
#  'bianca stratford  sophomore do not even think about it',
#  'why not',
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'you could consecrate with her my friend',
#  "that is her  bianca's sister",
#  'the mewling rampalian wretch herself',
#  'unlikely but even so she still ca not go out with you  so what is the point',
#  'you wanna go out with him',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'that is what i just said',
#  'i thought you hated those people',
#  'hey  i have gotta have a few clients when i get to wall street',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'are you kidding  he will piss himself with joy  he is the ultimate kiss ass',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'dead at fortyone',
#  'okay  i was not sure',
#  "it's her favorite band",
#  'hell i have just been going over the whole thing in my head and ',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  "no i ' m not",
#  'best case scenario you are back on the payroll for awhile',
#  'yeah  we will see',
#  'i have retrieved certain pieces of information on miss katarina stratford i think you will find helpful',
#  'do not make me do it man',
#  "it's off the whole thing",
#  'she is partial to joey not me',
#  "i don ' t know  i decided not to nail her when she was too drunk to remember it",
#  'she just needs time to cool off i will give it a day',
#  'she kissed me',
#  'you get the girl',
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'they are running the rest of me next month',
#  'not at all',
#  'and why would i do that',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'but you would go out with her if you had the cake',
#  'you are gonna pay me to take out some girl',
#  'i ca not date her sister until that one gets a boyfriend  and that is the catch she does not want a boyfriend',
#  'how much',
#  'fine thirty',
#  'fifty and you have got your man',
#  'i am on it',
#  'watching the bitch trash my car does not count as a date',
#  'i got her under control she just acts crazed in public to keep up the image',
#  'forget it',
#  'forget her sister then',
#  "a deal's a deal",
#  'do what',
#  'get her to act like a human',
#  "enough with the barbie n' ken shit i know",
#  'nope  just came by to chat',
#  'we do not chat',
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'we are not',
#  'does this conversation have a purpose',
#  "so what you need to do is recruit a guy who will go out with her  someone who's up for the job",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'what  we took bathes together when we were kids',
#  "hey  it's all for the higher good right",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'block e',
#  'just a little',
#  'an attempted slit',
#  'you could always go with me  i am sure william has some friends',
#  'william did not even go to high school',
#  'that is never been proven',
#  'neither has his heterosexuality',
#  'does it matter',
#  'if i was bianca it would be any school you want precious  do not forget your tiara',
#  'no fear',
#  'who cares',
#  'i did not have a choice',
#  'you did not have a choice  where is kat and what have you done with her',
#  'i did bianca a favor and it backfired',
#  'you did not',
#  'i got drunk  i puked  i got rejected it was big fun',
#  'well i guess we are not since we do not have dates ',
#  'listen to you  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we wo not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'oh good  something new and different for us',
#  "oh honey  tell me we have not' progressed to fullon hallucinations",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'my mission in life',
#  'oh right  friday',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  'i know a lot more than that',
#  'i do not really think you warrant that strong an emotion',
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'you  covered in my vomit',
#  'i was in the laundromat i saw your car thought i would say hi',
#  'depends on the topic my fenders do not really whip me into a verbal frenzy',
#  'that is what you want is not it',
#  'do you mind  you are sort of ruining it for me',
#  'you know who the raincoats are',
#  'why do not you',
#  'i am getting trashed man is not that what you are supposed to do at a party',
#  'i say do what you wanna do',
#  'funny you are the only one',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'i know just let me sleep',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  'you do not care if i die',
#  'sure i do',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'just let me sit down',
#  'i know  it would have to be a pretty big deal to get you to mainline tequila you do not seem like the type',
#  "hey man    you don ' t think i can be cool  you do not think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'you know what they say',
#  "but it's gigglepuss  i know you like them  i saw you there",
#  'then why would you ask',
#  'why would you lie',
#  'do what',
#  'my father would not approve of that that',
#  'you do not strike me as the type that would ask permission',
#  "i am gettin' there",
#  'he just wants me to be someone i am not',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'you  are so ',
#  'do not for one minute think that you had any effect whatsoever on my panties',
#  'so what did i have an effect on ',
#  'other than my upchuck reflex nothing',
#  'look up sunshine',
#  "c'mon  it's not that bad",
#  "try lookin' at it from this angle",
#  "forget it  i am stayin'",
#  'you want me to climb up and show you how to get down',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'i dazzled him with my wit',
#  'yeah well do not let it get out',
#  'so what is your excuse',
#  'acting the way we do',
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'then you screwed up',
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'you are sweet  and sexy  and completely hot for me',
#  'you are amazingly selfassured has anyone ever told you that',
#  'go to the prom with me',
#  'you know what i mean',
#  'no i wo not go with you',
#  'why not',
#  "because i do not want to it's a stupid tradition",
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  "nothing  there's nothing in it for me just the pleasure of your company",
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  'look i am   sorry  that i questioned your motives  i was wrong',
#  'it gets worse  you still have your freshman yearbook',
#  'you were paid to take me out  by  the one person i truly hate  i knew it was a setup',
#  'it was not like that',
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  'i did not care about the money',
#  'i thought you could use it when you start your band',
#  'is that right',
#  'yeah but then i fucked up i fell for her',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  "don ' t you even dare  ",
#  'i thought we decided you were going to school here  at u of 0',
#  'you decided',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why ca not we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  'so what i want does not matter',
#  'you are eighteen  you do not know what you want  you wo not know until you are fortyfive and you do not have it',
#  'i want to go to an east coast school i want you to trust me to make my own choices  i want ',
#  'yeah  she left with some bikers big ones  full of sperm',
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  'no  impressed',
#  "oh christ  do not tell me you have changed your mind  i already sent 'em a check",
#  'expressing my opinion is not a terrorist action',
#  'the point is kat  people perceive you as somewhat ',
#  'just smack her now',
#  'yeah  i guess',
#  'oh yeah',
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  'what is it with this chick  she have three tits',
#  'dorsey can plow whoever he wants i am just in this for the cash',
#  'so dorsey can get the girl',
#  'we are your guys',
#  'just for now',
#  "i am likin' you guys better",
#  "no  i have got a sweetpayin' job that i am about to lose",
#  'sweet love renew thy force',
#  'man  do not say shit like that to  me people can hear you',
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  'with the teeth of your zipper',
#  'touch of the flu',
#  'i am at a loss then  what should we talk about your year of absence',
#  'what is to discuss',
#  'see you next week',
#  'make anyone cry today',
#  'sarah lawrence is on the other side of the country',
#  'pirate  no question',
#  'kissing  is that what you think happens  kissing is not what keeps me up to my elbows in placenta all day',
#  'dr ruth',
#  'but  who  what ',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  "that ' s what i thought",
#  "the water's going putrid in the barrels",
#  'you will be drinking your own piss for the glory of spain and admiral colon  bastard',
#  'ah leave him alone  he is doing no harm',
#  'with a face like that  i do not want you looking at me  you hear',
#  'we will all go crazy',
#  'we left three weeks ago alonso ca not be that near',
#  'ca not be that far i say  also i do not like the smell of the sea around here  smells like a cunt bad sign',
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'then you cannot ignore that according to their calculations the circumference of the earth is approximately  22000 leagues or more  which makes the ocean uncrossable',
#  'if they agree to follow me yes',
#  'no  the portuguese have already discovered blackskinned people  i too will find other populations  and bring them to the word of god',
#  "did he not choose a carpenter's son to reveal himself to the world",
#  'blind faith is what i consider heresy',
#  'the judgment is ours',
#  'naturally  but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography',
#  'on the contrary your eminence  it seems to me the man is preparing his own cross',
#  'what a tragedy what a waste of a life',
#  'a waste  let me tell you something arojaz  if your name or mine is ever remembered  it will only be because of his',
#  'i know',
#  'i have not given you much of a life',
#  "well that is true  i have a child by a man who wo not marry me  who's always leaving",
#  'are we going to argue',
#  'i would love to argue with you sometimes  but you are never here',
#  'i find that hard to believe',
#  'thank god',
#  'i do not want you to wait for me',
#  'that is something you ca not decide',
#  'you do not usually ask',
#  'i can arrange for the queen to take fernando and diego into her service',
#  'they tried but i did not let them',
#  'not everything do you think i care  i am a free man again  riches do not make a man rich they only make him busier',
#  'i am busy inside',
#  'i ca not keep my eyes off you  i would like to catch up with all the moments i did not spend with you',
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'bartolome and giacomo colon',
#  'yes i remember',
#  'appointment to what',
#  'viceroy of the west indies',
#  'congratulations  then i am free to search for the mainland',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i am afraid this is not the worst news',
#  'there will be a time',
#  'you promise  do you swear on st christopher',
#  'yes yes i do on all of them',
#  'this time with me',
#  'not bad',
#  'i am not listening father  but i ca not help hearing',
#  'he asks when he can come to visit you  he left his address',
#  'he never had one except aboard my ships',
#  'really  god i would not know where to start and yet',
#  'tell me the first thing that comes to your mind',
#  'i am not bargaining',
#  'then you are too ambitious',
#  'if you wo not accept our proposal we will simply find someone who will',
#  ' for a commoner',
#  'don bobadilla is already a judge my dear don cristobal',
#  'good  we are also in need of judges  except there are no thieves',
#  'what  do i have so many already',
#  'to rise so high in so short a time is a dangerous occupation  a little hypocrisy goes a long way',
#  'call them',
#  'look out of that window',
#  'roofs towers palaces spires',
#  'all of them created by people like me',
#  'what is it  a tribe  an island',
#  'island  far',
#  'tell the chief we thank him',
#  'chief knows',
#  'tell him his country is very beautiful  tell him we are leaving men here  to build a fort',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'he has medicine  tell him we admire his people',
#  'he understands',
#  'ask him if he will help',
#  'you did the same to your god',
#  'you never learned how to speak my language',
#  'father i am doing what i think is the best for him  and he has the teacher i would have chosen for myself',
#  'that is what it says',
#  'how did you manage it',
#  'with some difficulty  i had to promise them you were not a total fool',
#  'to open a new route to asia  at the moment there are only two ways of reaching it',
#  'ignorance  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'so was christ',
#  'i will try to remember that marchena',
#  'father marchena',
#  'passion is something one cannot control',
#  'you get so carried away when you are being contradicted',
#  'i have been contradicted all my life eternity',
#  'only god knows the meaning of such words my son',
#  'wait  i have waited seven years already  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'damn god',
#  'colon  do not',
#  'forgive me father  for i have sinned',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'i am not sure it could be twice the distance',
#  'if i tell them they wo not follow me  you know that i am right father  you trust me',
#  'my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you do not i will',
#  'you are bound by an oath father',
#  'give me absolution',
#  'you will always be older than me father',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  'i do not know i have the impression that i did not change that much  i still ca not accept the world as it is',
#  'what did they say about granada before today',
#  'that she was impregnable',
#  'surely you can do anything you want',
#  'you show no inclination to speak otherwise',
#  'thirty seven your majesty and you',
#  'they come and go as naked as the day god created them',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  'your majesty  some men are content to read about things  i must see them with my own eyes  i cannot be other than i am',
#  'the indians have no such word don moxica',
#  'if you want to keep your head on your shoulders you will do as i say',
#  'we do not need to know',
#  'my horse does not work',
#  'you did not hear me don colon  not my horse',
#  'god be with us admiral',
#  'and what do you think mendez',
#  'well i surely know what a quadrant is  but i have never seen it used at night before',
#  'come over here',
#  'twenty eight',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'we ca not be',
#  'six days ago yes',
#  'you must be mad',
#  'we have to keep the hopes of these men alive',
#  'we are on the verge of a mutiny colon',
#  'you think i do not know that',
#  'we are lost',
#  'the land is there  i know it',
#  'you do not know anything  listen colon these are my ships right so i am telling you we are turning back',
#  'and then what  half of the water has gone the rest is nearly putrid you know that',
#  'jesus maria  i should have never listened to you',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward  think about that',
#  'you tell that to them',
#  'you are right  let the men decide',
#  'yes your majesty',
#  'never your majesty  although',
#  'yes  it would be a pity would not it  call him back',
#  'we were not expecting immediate profits were we  we must have faith  we must give time for time',
#  'is this true brother buyl',
#  'he must be replaced',
#  'and who would you think of for such a task',
#  'then why',
#  'because he is not afraid of me',
#  'i am not your lawyer until i see the money',
#  'here  i have your money',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  'he has the camera  he took the movie',
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me',
#  'i am invoking rights  this man is represented by counsel  i am coming with him',
#  'you bring the cigarettes',
#  'oh sure',
#  'i was all of these',
#  'well you did not appreciate the severity of it until recently  no question about that',
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  'do not worry about him  think about yourself',
#  'what about my movie rights  book rights',
#  'look i have not really focused on that kind of thing',
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  "but it's",
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'give me another one please',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'yeah he hated me from day when i was born  put it out  can you put the cigarette out',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  'can i see your back',
#  "i do not think it's abuse i think it's torture",
#  "officers there's your killer do your duty arrest him",
#  'yes but he was a cop',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  'i will if they do not send me back',
#  'they wo not until this is over',
#  'somewhere else',
#  'sothe station is empty',
#  'yeah  this way',
#  'yes i considered it',
#  'did you ever turn tricks before',
#  'what are you asking me',
#  'i am just trying to find out who you are',
#  'i know',
#  "i still ca not believe eddie's gone",
#  'i am sorry',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  'if you were my boyfriend i would suggest you find another girlfriend that is not going to jail tenthousand miles away',
#  'no matter what happensi am glad i met you',
#  'i am glad i met you',
#  'in the kitchen',
#  'i will make some for us',
#  'i will get my clothes',
#  'pouring it out',
#  'do you really want me to forget about you',
#  'i do not want to drag you down with me',
#  'daphne i',
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'go on',
#  'if i tell you will you arrest me',
#  'arrest you for what  why would we arrest you',
#  'no no do not talk to immigration',
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'you are a cop  you will never believe me',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'yeah sure  beep me when you are ready for the press conference',
#  'who do you think chief',
#  'then why did not you talk to the reporter',
#  "'cause we got more important things to do like finding out who did it",
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower  did you take one too',
#  'no  nothing happened',
#  'okay  but not water sports',
#  'forgot  you handcuffed a civilian to a tree',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'end my career',
#  "there's nothing to talk about  get a good lawyer  you are suspended until your trial",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  "you do that wiseguy  now let's solve this thing before eddie flemming does",
#  'yeah  he finished awhile ago',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that',
#  'vodka tonic',
#  'maybe you could just put in a shot of martell',
#  'you ready',
#  'a timer',
#  "takin' a bath",
#  'any id',
#  'still unknown but we are running prints kid over there caught the case',
#  "it's okay",
#  'stay with her',
#  'no  i am okay',
#  'i know  relax  take it easy  do not worry we will get those fuckers',
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  "homicide miss hearn  it's detective eddie flemming  open up",
#  'we do not have her id yet but one of your girls was killed last night at the king edward hotel',
#  "oh my gd  honey  honey's dead",
#  'what are you saying',
#  'daphne  another guy came in asking me about her too',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he would not turn his videocamera off me",
#  'he had a videocamera  where is she quickly',
#  "she washes hair up at ludwig's  a salon on 63rd and madison",
#  'no what is it',
#  'why do not you explain it bobby  hey camello  you mind punching a hole in the floor',
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  'well just so you know i do not care about that stuff',
#  'nah why should you',
#  'i do not even watch tv',
#  'good  good  commendable',
#  'sure  but i would like to ask you something  you got a problem with me',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report",
#  'who says she is a suspect',
#  'there was not a fire  there will be nothing for you to do',
#  'i can watch you eddie  maybe i will learn something',
#  'this is not homicide school',
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  'stay here',
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'but what if it does  you might need my help',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over',
#  'better than one',
#  "i am on my way with eddie  ludwig's 63rd and madison  the suspects might be there already",
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'of course',
#  'she just saw two of her friends killed they probably threatened her',
#  'is that all there is',
#  'something back home',
#  'raw deal',
#  'you wanna talk to her alone',
#  'i do not have a girlfriend',
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  'you know what i am saying here',
#  'women like that have a way of turning professionals into amateurs',
#  "well you shoulda because nobody's gonna believe you did notincluding me",
#  'i took her there for a shower and that is it',
#  'just a shower',
#  "well it's not up to you to decide whether she is innocent or not  do not you understand that is why you are a professional",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  'good  be tough to the end  actor who plays you will want to die like hero',
#  'if you kill me and film it you are putting a noose around your neck',
#  "we do not know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you ca not do that  c'mon",
#  'is it drug related',
#  'we do not know  when i have more i will let you know',
#  'i ca not talk right now  we have some things to take care of',
#  'i really ca not give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'do you have the suspect in custody',
#  "yeah  now's not a good time",
#  'i ca noti ca not answer you just because you want me to answer you',
#  'you did not have to embarrass me in front of my colleagues  you could give me something',
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  'alright alright eddie  do not patronize me',
#  'i am not',
#  'yes you are  i am not just some reporter  i do not just stick a microphone in your face  you could give me something',
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  'you were merciless  you did not give a shit if you got me or not',
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'you are not so bad yourself',
#  "could be leon's",
#  'jesus  and last week you came over with blood on your shoes  what am i going to do with you',
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  "okay  okay  hold that thought just for a second  they only call me when it's an emergency  just hold that thought  can you call back",
#  'that is good',
#  'okay  that is great  but i ca not go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk",
#  'patronizing you nay i love you',
#  'i love you',
#  'yeah  i promise',
#  'thank you',
#  'do not be late',
#  'i am not moody',
#  'not what  who',
#  'yeah  and he still went to the party',
#  'you are worried for my safety  i am touched',
#  'okay  you ready',
#  'yeah yeah  jesus',
#  'again  i did not wanna do it the first time',
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'dog food',
#  'no  are you proposing',
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  'what  it does not work that way',
#  'if you do not want my film  i will call another show  and they will show it',
#  'wait a minute  wait a minute',
#  'come alone  bring cash  and we will talk about surrendering',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'tommy take a walk',
#  'you will be my first',
#  'get down on your knees',
#  'the sheraton  on broadway  room 210 go get oleg  he will kill you',
#  'let her go  let her go',
#  'if he does not lower his gun i will fucking kill her',
#  'where is czech girl',
#  'baby i am anybody you want me to be i am a little schoolgirl i am mommy i am a czech girl',
#  'i ordered a czech girl  daphne you know her',
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'i like to talk to the person who runs the service  can you give me address',
#  "look man i do not give a shit if you want sex or not but you are payin' for my time",
#  "alright alright  do not hurt me please it's in my book in my purse",
#  'yes sir',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'can you show me  sir no cameras in the fis area',
#  'is there a problem',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  'he does not speak english',
#  "new york's finest  this is his case",
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'million  the killer gets one million dollars for a television interview',
#  'i want to document my trip to america',
#  'do not speak russian',
#  'why  why do i always have to speak to you in czech',
#  'we have no money  come on',
#  'why should i carry your bag  i am not a dog',
#  "i am not filming  i am watching milos die  it's just like a move but realer",
#  'you said speak czech',
#  'how you erase this',
#  'i will do it  do not hurt my camera',
#  'whatever we do  we fuck her right',
#  'oleg get in bathroom stay there and shut up',
#  'shut up',
#  'does it hurt',
#  'do not want to film this',
#  'the video of milos and tamina  i told you to erase it',
#  'i did',
#  "and the whore's murder  you did not erase that either did you  do not lie i wo not be angry",
#  'why not',
#  'put the camera down oleg',
#  "what does it look like  it's an address book",
#  'sit down',
#  'this way  hold it this way  good',
#  'the one who got caught in the bathroom  george michael',
#  'shut up  look',
#  'bad last moment  i cut it out',
#  'be quiet  watch',
#  "yes  but there's only one problem  you want credit but the problem is  i do not share credit",
#  'no i do not get that',
#  'you think you are a director  you are a fucking little small russian piece of shit  and i hate you  i fucking hate you',
#  'did you hurt her',
#  'you know mei never hurt anybody where is the money',
#  'ha ha',
#  'look at the way we live  i am a plumber you think i would be working if i had money',
#  'a job',
#  'yes the money is good',
#  'as a plumber',
#  "it's easy to learn",
#  'a job  as a plumber  you think i come to america to work',
#  'we started over you can too',
#  'you spent all the money while i was in prison  now you tell me to get a job fixing toilets',
#  'you have got a call',
#  'you want the tape  there it is',
#  'of course he is moody  he thinks he is in love',
#  'in love  with who',
#  'this footage will work in your favor when the jury sees this  no matter what cutler tries they will convict him',
#  'if i did not put it on somebody else would  i was his friend',
#  'do not give me that fucking shit',
#  'what do you mean you know  he told you he was gonna propose to me',
#  'well he',
#  'i want to hear everything he said',
#  'i am trying to tell you',
#  'alright  go ahead',
#  'that morning  he was talking to me and leon about marriage',
#  'okay  you are a czech national and you are a russian national  how do you know one another',
#  'then answer my questions  where were you planning to stay during the two weeks that you are here',
#  'new york',
#  'yes we are in new york now  but where are you planning to stay in new york',
#  'a cheap hotel',
#  'what are you coming here to do',
#  'i am here for movies',
#  'moviesto be in the movies or to see movies',
#  'thanks  appreciate it',
#  'that is what it looks like to me',
#  "and while they are burning up they are still goin' down on each other  you got to hand it to them",
#  'yeah well some people got their priorities straight',
#  'evidence  of a homicide',
#  'no way  he is mine',
#  "we are takin' him  do not argue",
#  'he is my collar',
#  'well he killed my partner',
#  "he is yours but i take him in  i will drive him to the precinct you can have him but i am walkin' him in",
#  'look i do not have time for you get out of my way',
#  "alright how 'bout all your fuckin' money",
#  'fire department  firemen do not carry guns',
#  'oh yeah  guess again',
#  "hey  c'mon you ca not leave me like this  some freak will come by and stab me",
#  'a dog pissed on me  i am gonna sue you for this  you violated my civil rights',
#  'yeah i am religious  i am not an atheist like you  now are you guys gonna arrest me or not',
#  'how did you start the fire this time',
#  'i used an accelerant',
#  'yeah  what kind',
#  "hey by the way i am really sorry about your wife leavin' you",
#  'i heard  who the hell let them up there',
#  'i do not know you think eddie will give me his autograph',
#  'you see anything in the crowd  anybody suspicious',
#  "naw  i am sure the suspect's not here",
#  'oh yeah why',
#  "'cause eddie woulda locked him up by now",
#  'could you put out the cigar  part of the job is picking up scents',
#  'but you knew that right',
#  'he knew all along',
#  'you hear that question garcia',
#  'are not you tired',
#  'if i go home i wo not be able to fall asleep anyway',
#  'it hurts  aw jesus',
#  'lay down  stay down bobby',
#  'not good',
#  'what the hell happened',
#  'they were inside  they booby trapped her apartment',
#  'capra  that is not czech or russian who said he sounded russian',
#  'the clerk',
#  'look you ca not shoot him in cold blood',
#  'get outta here now  get in that car and drive away  do what i say or i will kill you too',
#  'yes  my psychiatrist did not insist that i stay on my medication',
#  'so you feel absolutely no responsibility for killing these people',
#  'and is not there a movie in the works about you',
#  'we are in negotiations that is correct',
#  'but does not the son of sam law prevent criminals from profiting from their crimes',
#  'that does not apply to me because i am not a criminal  i am not a criminal  i was not convicted',
#  'well how nice to see you again elena you are looking wonderful',
#  'right just a sec',
#  'sure what is it',
#  "well it's nothing really important but it's annoying",
#  'what is up',
#  "it's about my salary cheques",
#  'well what do you think we ought to do about it',
#  'i do not think we should make any fuss about it yet i am sure they will straighten it out',
#  'i must say i never did understand why they split us into two groups for training',
#  'no i never did either',
#  "i suppose so though of course there's a more sinister explanation",
#  'no as a matter of fact i did not',
#  'that seems very unlikely',
#  'yes i thought so',
#  'of course it would be very easy for us to find out now',
#  'that is true',
#  "yes but it's to fantastic to think that they would keep something from us",
#  'i know it would be almost inconceivable',
#  'but not completely inconceivable',
#  'i suppose it is not logically impossible',
#  'i guess it is not',
#  'still all we have to do is ask hal',
#  'yes i do not know what to make of it',
#  'i suppose computers have been known to be wrong',
#  "yes but it's more likely that the tolerances on our testing gear are too low",
#  "anyway it's just as well that we replace it better safe than sorry",
#  'are you reasonably awake',
#  'oh i am fine i am wide awake what is up',
#  "well hal's reported the aounit about to fail again",
#  'you are kidding',
#  'two units in four days how many spares do we have',
#  'two more',
#  "well i hope there's nothing wrong with the assembly on those other wise we are out of business",
#  'well now that we have got one that is actually failed we should be able to figure out what is happened and fix it',
#  'i guess you do not know your own strength old boy',
#  'i guess not',
#  'i think i will have to go out and burn them off',
#  'he is got a point',
#  'what is it hal',
#  'my fpc shows an impending failure of the antenna orientation unit',
#  'i understand hal we will take care of it please let me have the hard copy',
#  'sure dave what is up',
#  'you know that we checked the two aounits that you reported in imminent failure condition',
#  'yes i know',
#  'you probably also know that we found them okay',
#  'yes i know that but i can assure you that they were about to fail',
#  'hal is there anything bothering you  anything that might account for this problem',
#  'well do not worry about it',
#  'and do not you worry about it',
#  'is your confidence in me fully restored',
#  'yes it is hal',
#  'well that is a relief you know i have the greatest enthusiasm possible for the mission',
#  'yes it is',
#  'i suppose you are pretty broken up about it',
#  'repairing the antenna is a pretty dangerous operation',
#  "it does not have to be hal it's more dangerous to be out of touch with earth let me have manual control please",
#  'i do not really agree with you dave my onboard memory store is more than capable of handling all the mission requirements',
#  'i am goin to do this myself hal let me have the control please',
#  'look dave your have probably got a lot to do i suggest you leave it to me',
#  'hal switch to manual hibernation control',
#  'i am fine daddy when are you coming home',
#  'yes i know that sweetheart',
#  'are you coming to my party',
#  'no i am sorry darling i told you i wo not be home for a few days',
#  'when are you coming home',
#  'in three days darling i hope',
#  "mommy's out to the hair dresser",
#  'where is mrs brown',
#  'she is in the bathroom',
#  'okay sweetheart well i have to go now tell mommy that i called',
#  'how many days until you come home',
#  'three darling one two  three be sure to tell mommy i called',
#  'thank you daddy',
#  'i will wish you a happy birthday now and i will see you soon all right darling',
#  'yes daddy',
#  "'bye 'bye now sweetheart",
#  'goodbye daddy',
#  'thank you',
#  'well how is it going back there',
#  'i suppose it was bound to happen sooner or later',
#  'berkeley told me that they think it came from contamination on a returning mars flight',
#  'yes well whatever it is they are certainly not fooling around this is the first flight they allowed in for more than a week',
#  'i was working out what this trip must cost taking him up there by himself and coming back empty',
#  "i will bet it's a fortune",
#  'oh she is growing up very fast as a matter of fact she is six tomorrow',
#  'oh that is such a delightful age',
#  'how is gregor',
#  'he is fine but i am afraid we do not get a chance to see each other very much these days',
#  'well where are all of you off to',
#  'well that does sound very odd',
#  'no thank you and i am afraid now i really must be going',
#  'well i hope that you and your wife can come to the iac conference in june',
#  "thank you it's been a great pleasure to meet all of you dr smyslov",
#  'please it really does not matter',
#  'well did you have a pleaant flight',
#  'yes very pleasant',
#  'well shall we go through documentation',
#  'i suppose you saw the work on our new section while you were docking',
#  "yes it's coming along very well",
#  'yes really thank you very much',
#  'are you by any chance going up to your base at clavius',
#  'yesas a matter of fact i am',
#  "well it's just for the past two weeks there have been some extremely odd things happening at clavius",
#  'you mean you have not been able to get anyone at the base for ten days',
#  'that is right',
#  'i see',
#  'fortunately they did',
#  'well i am glad about that',
#  'dr smyslov i am not permitted to discuss this',
#  'how can you tell it was deliberately buried',
#  'by the deformation between the mother rock and the fill',
#  'any clue as to what it is',
#  'tomb shine surveymarker spare part take your choice',
#  'well not really at first glance black would suggest something sunpowered but then why would anyone deliberately bury a sun powered device',
#  'has it been exposed to any sun before now',
#  'i do not think it has but i would like to check that simpson what is the log on that',
#  "there's nothing like weightless sleep for a complete rest",
#  'when do we arrive at clavius',
#  'we are scheduled to dock in about seven hours is there anything we can do for you',
#  ...]

# %%
clean_questions
# Out:
# ['can we make this quick  roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad  again',
#  'well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  'you are asking me out  that is so cute what is your name again',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i ca not date until she does',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something',
#  'gosh if only we could find kat a boyfriend',
#  "c'esc ma tete this is my head",
#  "that is because it's such a nice one",
#  'how is our little find the wench a date plan progressing',
#  'you got something on your mind',
#  'you have my word  as a gentleman',
#  'how do you get your hair to look like that',
#  'sure have',
#  'i really really really wanna go but i ca not  not unless my sister goes',
#  'she is not a',
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'you know chastity',
#  'i looked for you back at the party but you always seemed to be occupied',
#  'i was',
#  'well no',
#  'do you listen to this crap',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'i figured you would get to the good stuff eventually',
#  'what good stuff',
#  'the real you',
#  'she okay',
#  'they do to',
#  'is he oily or dry',
#  'i have to be home in twenty minutes',
#  "you think you ' re the only sophomore at the prom",
#  'queen harry',
#  'hey sweet cheeks',
#  'hi joey',
#  'listen i want to talk to you about the prom',
#  'where have you been',
#  'i have the potential to smack the crap out of you if you do not get out of my way',
#  'oh my god does this mean you are becoming normal',
#  'what do you think',
#  "you are ruining my life'  because you wo not be normal i ca not be normal",
#  'what is normal',
#  'ca not you forget for just one night that you are completely wretched',
#  'like i am supposed to know what that even means',
#  'you are so completely unbalanced',
#  'bianca i need to talk to you  i need to tell you ',
#  'listen i know you hate having to sit home because i am not susie high school',
#  'like you care',
#  'he was like a total babe',
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'he said everyone was doing it  so i did it',
#  'you did what',
#  'why did not you tell me',
#  'that is not',
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him just keep me locked away in the dark so i ca not experience anything for myself',
#  'not all experiences are good bianca you ca not always trust the people you want to',
#  'you looked beautiful last night you know',
#  'let go',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'is that woman a complete fruitloop or is it just me',
#  "now do not get upset daddy but there's this boy and i think he might ask",
#  'no you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  'but she does not want to date',
#  'daddy i ',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  'daddy people expect me to be there',
#  "oh god  it's starting",
#  'wear the belly before you go',
#  'daddy no',
#  "daddy i want to discuss the prom with you it's tomorrow night ",
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'i am missing something',
#  'always a pleasure brucie',
#  'did not have you pegged for a gigglepuss fan  are not they a little too preteen bellybutton ring for you',
#  'padua girls  one tall decent body the other one kinda short and undersexed',
#  'you the new guy',
#  'so they tell me',
#  'so  which dakota you from',
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'get out',
#  'how many people go here',
#  'that i am used to',
#  'that girl  i ',
#  'you burn you pine you perish',
#  'who is she',
#  'bianca stratford  sophomore do not even think about it',
#  'why do girls like that always like guys like that',
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'you know french',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'yeah just a minor encounter with the shrew',
#  "that is her  bianca's sister",
#  'i teach her french get to know her dazzle her with charm and she falls in love with me',
#  'what about him',
#  'what makes you think he will do it',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'you know if you do go out with bianca you would be set  you would outrank everyone strictly alist  with me by your side',
#  'i thought you hated those people',
#  'this is it  a golden opportunity patrick can ask katarina to the party',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'number one  she hates smokers',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'he is pretty',
#  'assail your ears for one night',
#  'you told me that part already',
#  'extremely unfortunate maneuver',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  'you humiliated the woman sacrifice yourself on the altar of dignity and even the score',
#  'and he means that strictly in a non prisonmovie type of way',
#  'what have you got for me',
#  'gigglepuss is playing there tomorrow night',
#  'cameron i am a little busy',
#  'what  are you talking about',
#  'what would you do to her',
#  'she hates you with the fire of a thousand suns   that is a direct quote',
#  "you makin' any headway",
#  'what is the worst',
#  'the vintage look is over kat have not you been reading your sassy',
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'hey  do you mind',
#  'leave my sister alone',
#  'two legs nice rack',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'you got it verona  i pick up the tab you do the honors',
#  'you are gonna pay me to take out some girl',
#  'i ca not date her sister until that one gets a boyfriend  and that is the catch she does not want a boyfriend',
#  'i ca not take a girl like that out on twenty bucks',
#  'take it or leave it  this is not a negotiation',
#  'when i shell out fifty i expect results',
#  'i am on it',
#  'watching the bitch trash my car does not count as a date',
#  'a hundred bucks a date',
#  'forget it',
#  "it's about time",
#  'how would you do it',
#  'do what',
#  'i do not know dorsey the limothe flowers  another hundred for the tux ',
#  'are you lost',
#  'nope  just came by to chat',
#  'we do not chat',
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'but she ca not go out with you because her sister is this insane head case and no one will go out with her right',
#  'does this conversation have a purpose',
#  "i hear you are helpin' verona",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'you better not fuck this up  i am heavily invested',
#  "who's that",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'mandella eat  starving yourself is a very slow way to die',
#  'what is this',
#  'the people at this school are so incredibly foul',
#  'william would never have gone to a state school',
#  'william did not even go to high school',
#  'that is never been proven',
#  'i appreciate your efforts toward a speedy death but i am consuming  do you mind',
#  'does it matter',
#  'you think this will work',
#  'what would he say',
#  'you went to the party  i thought we were officially opposed to suburban social activity',
#  'i did not have a choice',
#  'you did not have a choice  where is kat and what have you done with her',
#  'i did bianca a favor and it backfired',
#  'you did not',
#  'can you even imagine  who the hell would go to this a bastion of commercial excess',
#  'well i guess we are not since we do not have dates ',
#  'listen to you  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we wo not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'william  he asked me to meet him here',
#  "i mean woman  how ya doin'",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'pick you up friday then',
#  'the night i take you to places you have never been before  and back',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  'you hate me do not you',
#  'i do not really think you warrant that strong an emotion',
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'are you following me',
#  'you are not a big talker are you',
#  'excuse me',
#  'that is what you want is not it',
#  'you know these guys are no bikini kill or the raincoats but they are right up there',
#  'you know who the raincoats are',
#  'what is this',
#  'i am getting trashed man is not that what you are supposed to do at a party',
#  'i say do what you wanna do',
#  'you are not okay',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'this is so patronizing',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  'you do not care if i die',
#  'because then i would have to start taking out girls who like me',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'i hate him',
#  'i know  it would have to be a pretty big deal to get you to mainline tequila you do not seem like the type',
#  "hey man    you don ' t think i can be cool  you do not think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'and i am in control of it',
#  'no you were not',
#  'then why would you ask',
#  'i should do this',
#  'start a band',
#  'my father would not approve of that that',
#  'oh so now you think you know me',
#  "so what ' s up with your dad  he a pain in the ass",
#  'excuse me have you seen the feminine mystique  i lost my copy',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'unwelcome  i guess someone still has her panties in a twist',
#  'do not for one minute think that you had any effect whatsoever on my panties',
#  'so what did i have an effect on ',
#  'he left  i sprung the dickhead and he cruised on me',
#  'i guess i never told you i am afraid of heights',
#  "c'mon  it's not that bad",
#  'put your right foot there ',
#  "forget it  i am stayin'",
#  'the partridge family',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'a soft side who knew',
#  'yeah well do not let it get out',
#  'so what is your excuse',
#  'i do not like to do what people expect then they expect it all the time and they get disappointed when you change',
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'tell me something true',
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'no one else knows',
#  'you are amazingly selfassured has anyone ever told you that',
#  'is that a request or a command',
#  'no what',
#  'no i wo not go with you',
#  'why not',
#  'create a little drama  start a new rumor  what',
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  'how would you get a tux at the last minute',
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  "that ' s completely adorable",
#  'wait i',
#  'you were paid to take me out  by  the one person i truly hate  i knew it was a setup',
#  'it was not like that',
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  'a fender strat you bought this',
#  'besides i had some extra cash some asshole paid me to take out a really great girl',
#  'is that right',
#  'why is my veggie burger the only burnt object on this grill',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  'i know',
#  'i thought we decided you were going to school here  at u of 0',
#  'my insurance does not cover pms',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why ca not we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  'so what i want does not matter',
#  'you are eighteen  you do not know what you want  you wo not know until you are fortyfive and you do not have it',
#  'was that your sister',
#  'i do not understand the allure of dehydrated food  is this something i should be hip to',
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  'when i go',
#  'katarina stratford  my my  you have been terrorizing ms blaise again',
#  'i still maintain that he kicked himself in the balls  i was merely a spectator',
#  'am i supposed to feel better like right now  or do i have some time to think about it',
#  'cool pictures  you a fan',
#  'you think',
#  'what plan',
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  "i think i speak correctly when i say that cameron's love is pure  purer than say  joey dorsey's",
#  'that is where we can help you  with kat',
#  'you two are gonna help me tame the wild beast',
#  'are you telling me i am a   nonsmoker',
#  'i prefer to think of it simply as an alternative to what the law allows',
#  'so you got cozy with she who stings',
#  'you were right she is still pissed',
#  'sweet love renew thy force',
#  'i missed you',
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  'i do not understand patrick  you have not done anything asinine this week are you not feeling well',
#  'touch of the flu',
#  'why do not we discuss your driving need to be a hemorrhoid',
#  'you are completely demented',
#  'in the microwave',
#  'what is a synonym for throbbing',
#  'would you rather be ravished by a pirate or a british rear admiral',
#  'they will dance they will kiss they will come home  let her go',
#  'what do you wanna watch  we have got crap crap crap or crap',
#  'have a great time honey',
#  'what just happened',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  'i never seen heat like this  not even in las minas',
#  "the water's going putrid in the barrels",
#  'what are you listening to chicken ass',
#  'ah leave him alone  he is doing no harm',
#  "he is the devil's child",
#  'we should have seen land',
#  'we left three weeks ago alonso ca not be that near',
#  'you say asia can be found by sailing west',
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'your life and that of others',
#  'is that all that interests you gold',
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world',
#  'do not you realize your words could be considered heretical',
#  "the state has some reason to be interested in this man's proposition your eminence",
#  'the judgment is ours',
#  'it wo not be easy to get rid of your prophet now don sanchez',
#  'you can see for yourself',
#  'what a tragedy what a waste of a life',
#  'i could be gone for years',
#  'i know',
#  'i have not given you much of a life',
#  "well that is true  i have a child by a man who wo not marry me  who's always leaving",
#  'are we going to argue',
#  'perhaps i was never meant to live with a woman',
#  'she said yes',
#  'i am not asking you to swear to anything',
#  'i do not want you to wait for me',
#  'beatrix i want to ask you something',
#  'you do not usually ask',
#  'god you are so beautiful  i ca not believe no other man has ever taken you away from me',
#  'they took everything',
#  'ca not you stay with us a little',
#  'what is it now  tell me',
#  'i understand that you will soon be appointing governors for the islands  is it not so',
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'don alonso de bobadilla',
#  'my letters of appointment',
#  'appointment to what',
#  'viceroy of the west indies',
#  'how far from here',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i want to go with you',
#  'there will be a time',
#  'do you swear on all the holy saints in heaven',
#  'i have to explore the mainland',
#  'how are you feeling fernando',
#  'what are you listening to',
#  'what does he say',
#  'he asks when he can come to visit you  he left his address',
#  'i want you to tell me everything you remember father  from the beginning  everything',
#  'really  god i would not know where to start and yet',
#  'i remind you senor colon that you are in no position to bargain with me',
#  'i am not bargaining',
#  'and were you never ambitious excellency  or is ambition only a virtue among the nobles a fault for the rest of us',
#  'you defend yourself admirably',
#  'but we do have a lack of notaries you should contact my administration',
#  'don bobadilla is already a judge my dear don cristobal',
#  'you seem to have a special talent for making friends',
#  'what  do i have so many already',
#  'all i have to do is call the guards',
#  'i am not afraid of you  you are nothing but a dreamer',
#  'what do you see',
#  'roofs towers palaces spires',
#  'say not here  cuba',
#  'what is it  a tribe  an island',
#  'you come  you speak first',
#  'tell the chief we thank him',
#  'chief knows',
#  'to bring the word of god',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'we will work with his people  we want peace  ask the chief if he understands',
#  'he understands',
#  'you have to find them utapan  look what they did',
#  'utapan wo not you speak to me  you used to know how to speak to me',
#  'diego is a bright boy  a pleasure to teach  but so serious brothers should be raised together colon  even brothers from different mothers',
#  'god that is in a week',
#  'that is what it says',
#  'how did you manage it',
#  'why do you wish to sail west',
#  'how can you be so certain  the ocean is said to be infinite',
#  'ignorance  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'two minutes and already you are a dead man  do not let passion overwhelm you colon',
#  'i will try to remember that marchena',
#  'father marchena',
#  'passion is something one cannot control',
#  'you get so carried away when you are being contradicted',
#  'i have been contradicted all my life eternity',
#  'you must not give way to despair you must wait',
#  'wait  i have waited seven years already  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'all of them  just lies',
#  'in nomine patris et filius et spiritus sancti',
#  'i am listening my son',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'may god forgive you  you must tell them  you must tell your men',
#  'if i tell them they wo not follow me  you know that i am right father  you trust me',
#  'my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you do not i will',
#  'i believed in you',
#  'i suppose we are both old men now',
#  'i have to disagree',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  'the ocean is uncrossable',
#  'what did they say about granada before today',
#  'i cannot ignore the verdict of my council',
#  'may i speak freely',
#  'how old are you senor colon',
#  'do they have such thoughts',
#  'but without your brothers  nor are you to return to santo domingo or any of the other colonies  you may explore the continent',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  'and you say this is an indian vice by god  i do not see any kind of pleasure that would make this a sin',
#  'we lost cousins friends  we will wash this in blood',
#  'you want a war  fine  we are a thousand  they outnumber us by ten who will you kill  which tribe',
#  'we ca not raise the wheel without it',
#  'don moxica  we all have to work',
#  'due west captain mendez  and may god be with us',
#  "well it's the men sir  they wonder how you know our position we have lost sight from land days ago",
#  'and what do you think mendez',
#  'well i surely know what a quadrant is  but i have never seen it used at night before',
#  'what do you read',
#  'what is he doing',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'you lied  you cheated  we are way past 750 leagues',
#  'six days ago yes',
#  'you must be mad',
#  'we have to keep the hopes of these men alive',
#  'we are on the verge of a mutiny colon',
#  'you think i do not know that',
#  'we are lost',
#  'the land is there  i know it',
#  'you do not know anything  listen colon these are my ships right so i am telling you we are turning back',
#  'and then what  half of the water has gone the rest is nearly putrid you know that',
#  'jesus maria  i should have never listened to you',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward  think about that',
#  'you tell that to them',
#  'is that the man i knew treasurer sanchez',
#  'you were right don sanchez his demands could never be granted',
#  ' into a monk',
#  'every ship returns with a cargo of sick and dying  but with no gold the new world proves expensive your majesty',
#  ' but there is worse  he ordered the execution of five members of the nobility',
#  'then what do you suggest don sanchez',
#  'he must be replaced',
#  'i know i should not tolerate his impertinence',
#  'then why',
#  'are you my attorney  i am emil  i am insane',
#  'i am not your lawyer until i see the money',
#  'oh no  no  shit',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  'do not say anything',
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me',
#  "i brought you some letters  it's really fan mail  women mostly  one wants to buy you clothes another sent a check another wants a check",
#  'you bring the cigarettes',
#  'delusions and paranoia',
#  'i was all of these',
#  'well you did not appreciate the severity of it until recently  no question about that',
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  'do not worry about him  think about yourself',
#  'what about my movie rights  book rights',
#  'look i have not really focused on that kind of thing',
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  'this is not about money emil  i need your trust in me',
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'tell me about yourself  what you did as a young boy what your parents were like',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'that is what he did to me  he put cigarettes out on me',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  'i am abused  do not you think',
#  'so we kill someone famous and if we are caught we are sent to mental hospital',
#  'alright  that is a justifiable homicide',
#  'now i become custody of police department',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  'i will if they do not send me back',
#  'i ca not take you to my place',
#  'the men are out of quarters  practicing putting out fires',
#  'sothe station is empty',
#  'you considered becoming a prostitute',
#  'yes i considered it',
#  'so you were never a prostitute',
#  'what are you asking me',
#  'i am not a whore  i am not a whore',
#  'are you alright',
#  "i still ca not believe eddie's gone",
#  'is he your boyfriend',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  'a good immigration lawyer could stall the process  eddie recommended one',
#  'no matter what happensi am glad i met you',
#  'do you have coffee',
#  'in the kitchen',
#  'i will make some for us',
#  'what are you doing',
#  'forget about me  you have enough problems of your own',
#  'do you really want me to forget about you',
#  'i do not want to drag you down with me',
#  'i told your partner i ca not help  i did not see anything',
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'whether you tell us or not we will find out  better if it comes from you',
#  'if i tell you will you arrest me',
#  'are you here illegally  do not worry about that  we will talk to immigration they wo not deport you',
#  'a cop',
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'it was my decision not his',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'who did cause and origin',
#  'who do you think chief',
#  'then why did not you talk to the reporter',
#  'ladder 20 was on the rock for training we stopped there so she could get cleaned up',
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower  did you take one too',
#  'chief  mind if i take her',
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot',
#  'forgot  you handcuffed a civilian to a tree',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'but chief  over this',
#  "do not you guys understand  it's all about image  the better we look the more money i get to pay you guys overtime",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  'did the da videotape her deposition',
#  'yeah  he finished awhile ago',
#  'coffee for me i gotta slow down',
#  'vodka tonic',
#  'tomorrow  at lunch',
#  'what is he looking for',
#  'where is she',
#  "takin' a bath",
#  'any id',
#  'sorrypd only',
#  'the other side of the street  the guy with the videocamera  do not look  put her in the car  stay this side',
#  'are you hit',
#  'he got my gun  motherfucker was filming the whole time',
#  "who's there",
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  'what is wrong',
#  'we do not have her id yet but one of your girls was killed last night at the king edward hotel',
#  'boy she is so popular all the sudden',
#  'what are you saying',
#  'he said he was her cousin  i told him where she works  they were just here',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he would not turn his videocamera off me",
#  'he had a videocamera  where is she quickly',
#  'you know what that is right',
#  'no what is it',
#  "it's your crime scene now  you can do what you want",
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  'well just so you know i do not care about that stuff',
#  'nah why should you',
#  'i do not even watch tv',
#  'did you get a report from the me',
#  'sure  but i would like to ask you something  you got a problem with me',
#  'maybe you do not care about that either  prettiest suspect i have had in awhile',
#  'i will come with you',
#  'there was not a fire  there will be nothing for you to do',
#  'i can watch you eddie  maybe i will learn something',
#  'this is not homicide school',
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  "you goin' to the escort service",
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'i will let you know what happens',
#  'two heads',
#  "leon  meet us at 63rd and madison hair salon  ludwig's",
#  'you thirsty',
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'what are you hiding  why are you afraid',
#  'she just saw two of her friends killed they probably threatened her',
#  'why not',
#  'she is fucked  even if that story is true',
#  'look  let me talk to her  any leads i get they are all yours  just let me have a first crack at her',
#  'what would your girlfriend think of that',
#  'i do not have a girlfriend',
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  'hey  i am a professional',
#  "look eddie i am tellin' you  i did not touch her",
#  "well you shoulda because nobody's gonna believe you did notincluding me",
#  'i took her there for a shower and that is it',
#  'i told you you know i thought i was doing the right thing you know i think she is innocent',
#  "sowho's nicky",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  'so tabloids do not have to do re enactments  they going to have real movie this time',
#  'detective does it look like a murder',
#  "we do not know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you ca not do that  c'mon",
#  'is it drug related',
#  'detective  can you tell us what happened here',
#  'i understand but i noticed that the fire marshall is here with you  is this somehow related to the fire department',
#  'i really ca not give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'eddie are you okay',
#  'what is your problem  why would you snap at me  i just wanted a statement',
#  'i ca noti ca not answer you just because you want me to answer you',
#  'you did not have to embarrass me in front of my colleagues  you could give me something',
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  'alright alright eddie  do not patronize me',
#  'i am not',
#  'yes you are  i am not just some reporter  i do not just stick a microphone in your face  you could give me something',
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  'you were merciless  you did not give a shit if you got me or not',
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'look at this  you have blood on your shirt  whose is it',
#  "could be leon's",
#  'do not worry about the damn phone  i wo not answer it',
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  'oh my gd they want me to anchor  they want me to anchor tonight',
#  'well that is great',
#  'okay  that is great  but i ca not go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  'yeah  i will do that  as long as you are not patronizing me',
#  'patronizing you nay i love you',
#  'you promise',
#  'see you later  good luck',
#  'thank you',
#  'i think you are getting a little moody there eddie',
#  'so what is unique',
#  'that is unique',
#  'i hope this prick does not run  my knees are killing me  stay behind me',
#  'keep them out of my way',
#  'okay  you ready',
#  'any chance we can do that again',
#  'okay  you work in a vodka factory  i understand that  and what kind of work do you do',
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'are you married',
#  'come to 45 broadway  do not bring the police  come alone or you will be in my next film',
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  'what  it does not work that way',
#  'if you do not want my film  i will call another show  and they will show it',
#  'wait a minute  wait a minute',
#  'were you a fireman  that how you knew how to rig the apartment',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'you ca not kill me  you are not a cop just fireman with a gun  i bet you never shot anybody in your life',
#  "c'mon  pull the trigger  do it  oh look you are sweating  you do not have the balls",
#  'where is your partner',
#  'tell him to put his gun down',
#  'let her go  let her go',
#  'hi i am honey',
#  'where is czech girl',
#  'now i like to get business out of the way before we get down to pleasure  why do notchya put my money on the dresser',
#  "it's an outcall service run out of an apartment  i do not meet the other girls  are not you gonna get undressed",
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'listen to me  i do not want sex  just give me the address and then you go',
#  'give me the address',
#  'next  could i see your documents please',
#  'what is your intended purpose of your visit to the united states',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'please join us  come on forward',
#  'we are both from prague',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  'who is he',
#  'this all you want',
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'did you hear what i said',
#  'look  times square  just like in the movies',
#  'do not speak russian',
#  'look  new videocameras  color viewfinder  image stabilization solarization  night vision',
#  'turn that off  get the bags',
#  'turn that fucking thing off',
#  'speak english',
#  'you said speak czech',
#  'how you erase this',
#  'get in the bathroom',
#  'whatever we do  we fuck her right',
#  "gotta light the scene better  now it's more moody like a scene from the third man",
#  'shut up',
#  'oh shit  i hate looking at that',
#  'what is it',
#  'the video of milos and tamina  i told you to erase it',
#  'i did',
#  "and the whore's murder  you did not erase that either did you  do not lie i wo not be angry",
#  'why not',
#  'what is that',
#  'let me get a shot of it',
#  'sit down',
#  'in movie they make of us who do you think would act me',
#  'i am serious',
#  "this is my project  i say 'action'  i am the director  you are the talent you wait for me to say 'action'  and 'action'",
#  'i told you to cut that out before we handed in the tape',
#  'yes  before we hand in the next video  i put titles on it and my credit is going to read  directed by oleg razgul',
#  'you got that',
#  'no i do not get that',
#  'your sister said she did not know where you were so you should not write to her with return address if you are hiding',
#  'did you hurt her',
#  'we spent it',
#  'ha ha',
#  'i can get you a job',
#  'a job',
#  'yes the money is good',
#  'as a plumber',
#  "it's easy to learn",
#  'a job  as a plumber  you think i come to america to work',
#  'we started over you can too',
#  'what are you doing here',
#  'viewer discretion advised',
#  'is not he a little moody',
#  'of course he is moody  he thinks he is in love',
#  'and you you will pay for what you did',
#  'you outta be ashamed  ashamed of yourself',
#  'if i did not put it on somebody else would  i was his friend',
#  'i know',
#  'what do you mean you know  he told you he was gonna propose to me',
#  'well he',
#  'i want to hear everything he said',
#  'i am trying to tell you',
#  'alright  go ahead',
#  'yeshe is my friend',
#  'i speak english',
#  'then answer my questions  where were you planning to stay during the two weeks that you are here',
#  'new york',
#  'yes we are in new york now  but where are you planning to stay in new york',
#  'a cheap hotel',
#  'what are you coming here to do',
#  'i am here for movies',
#  'no  go ahead',
#  'so the way you see it two crack heads burned themselves up',
#  'that is what it looks like to me',
#  "and while they are burning up they are still goin' down on each other  you got to hand it to them",
#  'what was that',
#  'i will take him',
#  'no way  he is mine',
#  "we are takin' him  do not argue",
#  'he is my collar',
#  'well he killed my partner',
#  "got any spare change  how 'bout a spare twenty",
#  'look i do not have time for you get out of my way',
#  'okay you are under arrest  now you happy',
#  'fire department  firemen do not carry guns',
#  'i will send a cop back for you',
#  'you okay',
#  'what is that on your forehead max that is a nice attention getter',
#  'yeah i am religious  i am not an atheist like you  now are you guys gonna arrest me or not',
#  'how did you start the fire this time',
#  'i used an accelerant',
#  'yeah  what kind',
#  'where you been man  we got a celebrity',
#  'i heard  who the hell let them up there',
#  'i do not know you think eddie will give me his autograph',
#  'you see anything in the crowd  anybody suspicious',
#  "naw  i am sure the suspect's not here",
#  'oh yeah why',
#  'nah not at all  detective flemming  bobby korfin  my uncle tony worked with you at 21 back when you were a rookie',
#  "the smoke will permeate your nostrils  burn 'em out  let it run",
#  "you see eddie's face when i gave him the timer  wish i had a picture of it",
#  "how long they been livin' here",
#  "you go home  i am takin' your car and goin' back to the crime scene",
#  'are not you tired',
#  'bobby bobby  where are you hit',
#  'it hurts  aw jesus',
#  'how was it',
#  'get outta here',
#  'what the hell happened',
#  'room was registered to a francis capra',
#  'capra  that is not czech or russian who said he sounded russian',
#  'take the car  get outta here tommy',
#  'look you ca not shoot him in cold blood',
#  'your doctor',
#  'yes  my psychiatrist did not insist that i stay on my medication',
#  'look i am in here  you call this a career move',
#  'and is not there a movie in the works about you',
#  'we are in negotiations that is correct',
#  'but does not the son of sam law prevent criminals from profiting from their crimes',
#  'space stattion 5  lounge',
#  'hi frank coming in please',
#  'dave if you have a minute i would like your advice on something',
#  'sure what is it',
#  "well it's nothing really important but it's annoying",
#  'what is up',
#  "it's possible",
#  'well what do you think we ought to do about it',
#  'i do not think we should make any fuss about it yet i am sure they will straighten it out',
#  'i must say i never did understand why they split us into two groups for training',
#  'i suppose the idea was specialized training',
#  'yes you must have heard the rumour that went around during orbital checkout',
#  "i do not know all i heard is that there's something about the mission we were not told",
#  'that seems very unlikely',
#  'yes i thought so',
#  "just ask hal it's conceivable they might keep something from us but they would never keep anything from hal",
#  'not really though it is strange when you think about it it did not really make any sense to keep us apart during training',
#  "yes but it's to fantastic to think that they would keep something from us",
#  'i know it would be almost inconceivable',
#  'but not completely inconceivable',
#  'i suppose it is not logically impossible',
#  'i guess it is not',
#  'well that is something',
#  'yes i do not know what to make of it',
#  'i suppose computers have been known to be wrong',
#  "yes but it's more likely that the tolerances on our testing gear are too low",
#  'good morning how is it going',
#  'are you reasonably awake',
#  'oh i am fine i am wide awake what is up',
#  "well hal's reported the aounit about to fail again",
#  'i do not know hal said he thought it might be the assembly procedure',
#  'two units in four days how many spares do we have',
#  'two more',
#  "it's the last one",
#  'i did not do that frank i took particular care not to freeze them',
#  'i guess you do not know your own strength old boy',
#  'i guess not',
#  'i am sorry frank but i do not think i can answer that question without knowing everything that all of you know',
#  'sorry to interrupt the festivities dave but i think we have got a problem',
#  'what is it hal',
#  'the unit is still operational dave but it will fail within seventytwo hours',
#  'not now hal i would like to talk to you about something',
#  'sure dave what is up',
#  'you know that we checked the two aounits that you reported in imminent failure condition',
#  'yes i know',
#  'you probably also know that we found them okay',
#  "i am not questioning your word dave but it's just not possible i am not capable of being wrong",
#  'i am sorry about the misunderstanding hal',
#  'well do not worry about it',
#  'and do not you worry about it',
#  'is your confidence in me fully restored',
#  'yes it is hal',
#  'too bad about frank is not it',
#  'yes it is',
#  'the antenna has to be replaced',
#  'repairing the antenna is a pretty dangerous operation',
#  "it does not have to be hal it's more dangerous to be out of touch with earth let me have manual control please",
#  "if you are determined to revive the crew now i can handle the whole thing myself there's no need for you to trouble",
#  'i am goin to do this myself hal let me have the control please',
#  'look dave your have probably got a lot to do i suggest you leave it to me',
#  'i am at space station five darling how are you',
#  'i am having a party tomorrow',
#  'yes i know that sweetheart',
#  'are you coming to my party',
#  'no i am sorry darling i told you i wo not be home for a few days',
#  'when are you coming home',
#  'one two three can i speak to mommy',
#  "mommy's out to the hair dresser",
#  'where is mrs brown',
#  'she is in the bathroom',
#  'okay sweetheart well i have to go now tell mommy that i called',
#  'how many days until you come home',
#  'okay sweetheart have a lovely birthday party tomorrow',
#  'thank you daddy',
#  'i will wish you a happy birthday now and i will see you soon all right darling',
#  'yes daddy',
#  "'bye 'bye now sweetheart",
#  'oh thank you very much',
#  'thank you',
#  'well i have heard more and more people talk of an epidemic',
#  'i suppose it was bound to happen sooner or later',
#  'berkeley told me that they think it came from contamination on a returning mars flight',
#  'yes well whatever it is they are certainly not fooling around this is the first flight they allowed in for more than a week',
#  'i was working out what this trip must cost taking him up there by himself and coming back empty',
#  'and your charming little daughter',
#  'oh she is growing up very fast as a matter of fact she is six tomorrow',
#  'oh that is such a delightful age',
#  'how is gregor',
#  'he is fine but i am afraid we do not get a chance to see each other very much these days',
#  'clavius control came on the air just long enough to transmit their refusal',
#  'are you sure you wo not change your mind about a drink',
#  'no thank you and i am afraid now i really must be going',
#  'well gregor and i will look forward to seeing you',
#  'well thank you very much for being so understanding',
#  'please it really does not matter',
#  'well did you have a pleaant flight',
#  'yes very pleasant',
#  'yes i think so just about then',
#  'i suppose you saw the work on our new section while you were docking',
#  'are you quite sure',
#  'well as it happens i am on my way up to the moon',
#  'are you by any chance going up to your base at clavius',
#  'i am sorry but i am not sure i know what you mean',
#  "yes well at first we thought that was the explanation but it's been going on for the past ten days",
#  'you mean you have not been able to get anyone at the base for ten days',
#  'that is right',
#  'yes well i hope the crew got back safely',
#  'fortunately they did',
#  'this epidemic could easily spread to our base dr floyd we should be given all the facts',
#  'yes it does the subsurface structure shows that it was deliberately buried about four million years ago',
#  'how can you tell it was deliberately buried',
#  'by the deformation between the mother rock and the fill',
#  'but you do not have any idea as to what it is',
#  'any ideas about the colour',
#  'well not really at first glance black would suggest something sunpowered but then why would anyone deliberately bury a sun powered device',
#  'has it been exposed to any sun before now',
#  "oh marvellous it's the first real sleep i have had for the past two days",
#  "there's nothing like weightless sleep for a complete rest",
#  'when do we arrive at clavius',
#  ...]

# %%
len(clean_answers)
# Out:
# 155117

# %%
len(clean_questions)
# Out:
# 155117

# %%
intents = {
    "intents": []
}
for i in range(len(clean_answers)):
    intent = {
        "tag": str(i),
        "patterns": [],
        "responses": [],
        "context_set": ""
    }
    intent["patterns"].append(clean_questions[i])
    intent["responses"].append(clean_answers[i])
    intents["intents"].append(intent)

# %%
intents["intents"].append({"tag": "greeting",
         "patterns": ["Hi", "How are you", "Is anyone there?", "Hello", "Good day", "Whats up"],
         "responses": ["Hello!", "Good to see you again!", "Hi there, how can I help?"],
         "context_set": ""
        })

# %%
intents["intents"].append(
        {"tag": "goodbye",
         "patterns": ["cya", "See you later", "Goodbye", "I am Leaving", "Have a Good day"],
         "responses": ["Sad to see you go :(", "Talk to you later", "Goodbye!"],
         "context_set": ""
        })

# %%
intents["intents"].append(
        {"tag": "age",
         "patterns": ["how old", "how old is tim", "what is your age", "how old are you", "age?"],
         "responses": ["I am 18 years old!", "18 years young!"],
         "context_set": ""
        })

# %%
intents["intents"].append(
        {"tag": "name",
         "patterns": ["what is your name", "what should I call you", "whats your name?"],
         "responses": ["You can call me ChatBot.", "I'm a ChatBot!", "I'm ChatBot aka ChatBot from Scratch."],
         "context_set": ""
        })

# %%
intents
# Out:
# {'intents': [{'tag': '0',
#    'patterns': ['can we make this quick  roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad  again'],
#    'responses': ['well i thought we would start with pronunciation if that is okay with you'],
#    'context_set': ''},
#   {'tag': '1',
#    'patterns': ['well i thought we would start with pronunciation if that is okay with you'],
#    'responses': ['not the hacking and gagging and spitting part  please'],
#    'context_set': ''},
#   {'tag': '2',
#    'patterns': ['not the hacking and gagging and spitting part  please'],
#    'responses': ["okay then how 'bout we try out some french cuisine  saturday  night"],
#    'context_set': ''},
#   {'tag': '3',
#    'patterns': ['you are asking me out  that is so cute what is your name again'],
#    'responses': ['forget it'],
#    'context_set': ''},
#   {'tag': '4',
#    'patterns': ['the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i ca not date until she does'],
#    'responses': ['seems like she could get a date easy enough'],
#    'context_set': ''},
#   {'tag': '5',
#    'patterns': ['unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something'],
#    'responses': ['that is a shame'],
#    'context_set': ''},
#   {'tag': '6',
#    'patterns': ['gosh if only we could find kat a boyfriend'],
#    'responses': ['let me see what i can do'],
#    'context_set': ''},
#   {'tag': '7',
#    'patterns': ["c'esc ma tete this is my head"],
#    'responses': ['right  see  you are ready for the quiz'],
#    'context_set': ''},
#   {'tag': '8',
#    'patterns': ["that is because it's such a nice one"],
#    'responses': ['forget french'],
#    'context_set': ''},
#   {'tag': '9',
#    'patterns': ['how is our little find the wench a date plan progressing'],
#    'responses': ["well there's someone i think might be "],
#    'context_set': ''},
#   {'tag': '10',
#    'patterns': ['you got something on your mind'],
#    'responses': ['i counted on you to help my cause you and that thug are obviously failing are not we ever going on our date'],
#    'context_set': ''},
#   {'tag': '11',
#    'patterns': ['you have my word  as a gentleman'],
#    'responses': ['you are sweet'],
#    'context_set': ''},
#   {'tag': '12',
#    'patterns': ['how do you get your hair to look like that'],
#    'responses': ["eber's deep conditioner every two days and i never ever use a blowdryer without the diffuser attachment"],
#    'context_set': ''},
#   {'tag': '13',
#    'patterns': ['sure have'],
#    'responses': ['i really really really wanna go but i ca not  not unless my sister goes'],
#    'context_set': ''},
#   {'tag': '14',
#    'patterns': ['i really really really wanna go but i ca not  not unless my sister goes'],
#    'responses': ["i am workin' on it but she does not seem to be goin' for him"],
#    'context_set': ''},
#   {'tag': '15',
#    'patterns': ['she is not a'],
#    'responses': ['lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies'],
#    'context_set': ''},
#   {'tag': '16',
#    'patterns': ['lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies'],
#    'responses': ['so that is the kind of guy she likes pretty ones'],
#    'context_set': ''},
#   {'tag': '17',
#    'patterns': ['so that is the kind of guy she likes pretty ones'],
#    'responses': ['who knows  all i have ever heard her say is that she would dip before dating a guy that smokes'],
#    'context_set': ''},
#   {'tag': '18',
#    'patterns': ['you know chastity'],
#    'responses': ['i believe we share an art instructor'],
#    'context_set': ''},
#   {'tag': '19',
#    'patterns': ['i looked for you back at the party but you always seemed to be occupied'],
#    'responses': ['i was'],
#    'context_set': ''},
#   {'tag': '20',
#    'patterns': ['i was'],
#    'responses': ["you never wanted to go out with 'me did you"],
#    'context_set': ''},
#   {'tag': '21',
#    'patterns': ['well no'],
#    'responses': ['then that is all you had to say'],
#    'context_set': ''},
#   {'tag': '22',
#    'patterns': ['do you listen to this crap'],
#    'responses': ['what crap'],
#    'context_set': ''},
#   {'tag': '23',
#    'patterns': ['what crap'],
#    'responses': ['me  this endless blonde babble i am like boring myself'],
#    'context_set': ''},
#   {'tag': '24',
#    'patterns': ['me  this endless blonde babble i am like boring myself'],
#    'responses': ['thank god  if i had to hear one more story about your coiffure'],
#    'context_set': ''},
#   {'tag': '25',
#    'patterns': ['i figured you would get to the good stuff eventually'],
#    'responses': ['what good stuff'],
#    'context_set': ''},
#   {'tag': '26',
#    'patterns': ['what good stuff'],
#    'responses': ['the real you'],
#    'context_set': ''},
#   {'tag': '27',
#    'patterns': ['the real you'],
#    'responses': ['like my fear of wearing pastels'],
#    'context_set': ''},
#   {'tag': '28',
#    'patterns': ['she okay'],
#    'responses': ['i hope so'],
#    'context_set': ''},
#   {'tag': '29',
#    'patterns': ['they do to'],
#    'responses': ['they do not'],
#    'context_set': ''},
#   {'tag': '30',
#    'patterns': ['is he oily or dry'],
#    'responses': ['combination  i do not know  i thought he would be different  more of a gentleman'],
#    'context_set': ''},
#   {'tag': '31',
#    'patterns': ['i have to be home in twenty minutes'],
#    'responses': ["i do not have to be home 'til two"],
#    'context_set': ''},
#   {'tag': '32',
#    'patterns': ["you think you ' re the only sophomore at the prom"],
#    'responses': ['i did'],
#    'context_set': ''},
#   {'tag': '33',
#    'patterns': ['queen harry'],
#    'responses': ["it's a gay cruise line but i will be like wearing a uniform and stuff"],
#    'context_set': ''},
#   {'tag': '34',
#    'patterns': ['hey sweet cheeks'],
#    'responses': ['hi joey'],
#    'context_set': ''},
#   {'tag': '35',
#    'patterns': ['hi joey'],
#    'responses': ["you are concentrating awfully hard considering it's gym class"],
#    'context_set': ''},
#   {'tag': '36',
#    'patterns': ['listen i want to talk to you about the prom'],
#    'responses': ["you know the deal  i can ' t go if kat does not go "],
#    'context_set': ''},
#   {'tag': '37',
#    'patterns': ['where have you been'],
#    'responses': ['nowhere hi daddy'],
#    'context_set': ''},
#   {'tag': '38',
#    'patterns': ['i have the potential to smack the crap out of you if you do not get out of my way'],
#    'responses': ['can you at least start wearing a bra'],
#    'context_set': ''},
#   {'tag': '39',
#    'patterns': ['oh my god does this mean you are becoming normal'],
#    'responses': ['it means that gigglepuss is playing at club skunk and we are going'],
#    'context_set': ''},
#   {'tag': '40',
#    'patterns': ['what do you think'],
#    'responses': ['i think you are a freak  i think you do this to torture me  and i think you suck'],
#    'context_set': ''},
#   {'tag': '41',
#    'patterns': ["you are ruining my life'  because you wo not be normal i ca not be normal"],
#    'responses': ['what is normal'],
#    'context_set': ''},
#   {'tag': '42',
#    'patterns': ['what is normal'],
#    'responses': ["bogey lowenstein's party is normal but you are too busy listening to bitches who need prozac to know that"],
#    'context_set': ''},
#   {'tag': '43',
#    'patterns': ['ca not you forget for just one night that you are completely wretched'],
#    'responses': ['at least i am not a clouted fen sucked hedgepig'],
#    'context_set': ''},
#   {'tag': '44',
#    'patterns': ['like i am supposed to know what that even means'],
#    'responses': ["it's shakespeare  maybe you have heard of him"],
#    'context_set': ''},
#   {'tag': '45',
#    'patterns': ['you are so completely unbalanced'],
#    'responses': ['can we go now'],
#    'context_set': ''},
#   {'tag': '46',
#    'patterns': ['bianca i need to talk to you  i need to tell you '],
#    'responses': ['i really do not think i need any social advice from you right now'],
#    'context_set': ''},
#   {'tag': '47',
#    'patterns': ['listen i know you hate having to sit home because i am not susie high school'],
#    'responses': ['like you care'],
#    'context_set': ''},
#   {'tag': '48',
#    'patterns': ['like you care'],
#    'responses': ["i do care but i am a firm believer in doing something for your own reasons not someone else ' s "],
#    'context_set': ''},
#   {'tag': '49',
#    'patterns': ['he was like a total babe'],
#    'responses': ['but you hate joey'],
#    'context_set': ''},
#   {'tag': '50',
#    'patterns': ['but you hate joey'],
#    'responses': ['now i do  back then was a different story'],
#    'context_set': ''},
#   {'tag': '51',
#    'patterns': ['now i do  back then was a different story'],
#    'responses': ['as in'],
#    'context_set': ''},
#   {'tag': '52',
#    'patterns': ['he said everyone was doing it  so i did it'],
#    'responses': ['you did what'],
#    'context_set': ''},
#   {'tag': '53',
#    'patterns': ['you did what'],
#    'responses': ['just once  afterwards i told him i did not want to anymore  i was not ready he got pissed  then he broke up with me'],
#    'context_set': ''},
#   {'tag': '54',
#    'patterns': ['why did not you tell me'],
#    'responses': ['i wanted to let you make up your own mind about him'],
#    'context_set': ''},
#   {'tag': '55',
#    'patterns': ['that is not'],
#    'responses': ['i am not stupid enough to repeat your mistakes'],
#    'context_set': ''},
#   {'tag': '56',
#    'patterns': ['i am not stupid enough to repeat your mistakes'],
#    'responses': ['i guess i thought i was protecting you'],
#    'context_set': ''},
#   {'tag': '57',
#    'patterns': ['i guess i thought i was protecting you'],
#    'responses': ['god you are just like him just keep me locked away in the dark so i ca not experience anything for myself'],
#    'context_set': ''},
#   {'tag': '58',
#    'patterns': ['god you are just like him just keep me locked away in the dark so i ca not experience anything for myself'],
#    'responses': ['not all experiences are good bianca you ca not always trust the people you want to'],
#    'context_set': ''},
#   {'tag': '59',
#    'patterns': ['not all experiences are good bianca you ca not always trust the people you want to'],
#    'responses': ['i guess i will never know will i'],
#    'context_set': ''},
#   {'tag': '60',
#    'patterns': ['you looked beautiful last night you know'],
#    'responses': ['so did you'],
#    'context_set': ''},
#   {'tag': '61',
#    'patterns': ['let go'],
#    'responses': ['you set me up'],
#    'context_set': ''},
#   {'tag': '62',
#    'patterns': ['you set me up'],
#    'responses': ['i just wanted '],
#    'context_set': ''},
#   {'tag': '63',
#    'patterns': ['i just wanted '],
#    'responses': ['what to completely damage me  to send me to therapy forever what'],
#    'context_set': ''},
#   {'tag': '64',
#    'patterns': ['what to completely damage me  to send me to therapy forever what'],
#    'responses': ['no i just wanted'],
#    'context_set': ''},
#   {'tag': '65',
#    'patterns': ['is that woman a complete fruitloop or is it just me'],
#    'responses': ["it's just you"],
#    'context_set': ''},
#   {'tag': '66',
#    'patterns': ["now do not get upset daddy but there's this boy and i think he might ask"],
#    'responses': ['no you are not dating until your sister starts dating  end of discussion'],
#    'context_set': ''},
#   {'tag': '67',
#    'patterns': ['no you are not dating until your sister starts dating  end of discussion'],
#    'responses': ['what if she never starts dating'],
#    'context_set': ''},
#   {'tag': '68',
#    'patterns': ['what if she never starts dating'],
#    'responses': ['then neither will you  and i will get to sleep at night'],
#    'context_set': ''},
#   {'tag': '69',
#    'patterns': ['then neither will you  and i will get to sleep at night'],
#    'responses': ["but it's not fair  she is a mutant daddy"],
#    'context_set': ''},
#   {'tag': '70',
#    'patterns': ['but she does not want to date'],
#    'responses': ['exactly my point'],
#    'context_set': ''},
#   {'tag': '71',
#    'patterns': ['daddy i '],
#    'responses': ['and where are you going'],
#    'context_set': ''},
#   {'tag': '72',
#    'patterns': ['and where are you going'],
#    'responses': ['if you must know we were attempting to go to a small study group of friends'],
#    'context_set': ''},
#   {'tag': '73',
#    'patterns': ['if you must know we were attempting to go to a small study group of friends'],
#    'responses': ['otherwise known as an orgy'],
#    'context_set': ''},
#   {'tag': '74',
#    'patterns': ['otherwise known as an orgy'],
#    'responses': ["it's just a party daddy but i knew you would forbid me to go since gloria steinem over there is not going "],
#    'context_set': ''},
#   {'tag': '75',
#    'patterns': ['daddy people expect me to be there'],
#    'responses': ["if kat's not going you are not going"],
#    'context_set': ''},
#   {'tag': '76',
#    'patterns': ["oh god  it's starting"],
#    'responses': ["it's just a party daddy"],
#    'context_set': ''},
#   {'tag': '77',
#    'patterns': ['wear the belly before you go'],
#    'responses': ['daddy no'],
#    'context_set': ''},
#   {'tag': '78',
#    'patterns': ['daddy no'],
#    'responses': ['just for a minute'],
#    'context_set': ''},
#   {'tag': '79',
#    'patterns': ["daddy i want to discuss the prom with you it's tomorrow night "],
#    'responses': ['the prom  kat has a date'],
#    'context_set': ''},
#   {'tag': '80',
#    'patterns': ['the prom  kat has a date'],
#    'responses': ['no but'],
#    'context_set': ''},
#   {'tag': '81',
#    'patterns': ['no but'],
#    'responses': ["it's that hot rod joey right that ' s who you want me to bend my rules for"],
#    'context_set': ''},
#   {'tag': '82',
#    'patterns': ["it's that hot rod joey right that ' s who you want me to bend my rules for"],
#    'responses': ['he is not a hot rod  whatever that is'],
#    'context_set': ''},
#   {'tag': '83',
#    'patterns': ['he is not a hot rod  whatever that is'],
#    'responses': ['you are not going unless your sister goes  end of story'],
#    'context_set': ''},
#   {'tag': '84',
#    'patterns': ['you are not going unless your sister goes  end of story'],
#    'responses': ['fine  i see that i am a prisoner in my own house  i am not a daughter i am a possession'],
#    'context_set': ''},
#   {'tag': '85',
#    'patterns': ['i am missing something'],
#    'responses': ["i have a date daddy  and he ' s not a captain of oppression like some men we know"],
#    'context_set': ''},
#   {'tag': '86',
#    'patterns': ['always a pleasure brucie'],
#    'responses': ['did not have you pegged for a gigglepuss fan  are not they a little too preteen bellybutton ring for you'],
#    'context_set': ''},
#   {'tag': '87',
#    'patterns': ['did not have you pegged for a gigglepuss fan  are not they a little too preteen bellybutton ring for you'],
#    'responses': ['fan of a fan  you see a couple of minors come in'],
#    'context_set': ''},
#   {'tag': '88',
#    'patterns': ['padua girls  one tall decent body the other one kinda short and undersexed'],
#    'responses': ["just sent 'em through"],
#    'context_set': ''},
#   {'tag': '89',
#    'patterns': ['you the new guy'],
#    'responses': ['so they tell me'],
#    'context_set': ''},
#   {'tag': '90',
#    'patterns': ['so they tell me'],
#    'responses': ["c'mon  i am supposed to give you the tour"],
#    'context_set': ''},
#   {'tag': '91',
#    'patterns': ['so  which dakota you from'],
#    'responses': ['north actually  how would you   '],
#    'context_set': ''},
#   {'tag': '92',
#    'patterns': ['north actually  how would you   '],
#    'responses': ['i was kidding people actually live there'],
#    'context_set': ''},
#   {'tag': '93',
#    'patterns': ['i was kidding people actually live there'],
#    'responses': ['yeah  a couple  we are outnumbered by the cows though'],
#    'context_set': ''},
#   {'tag': '94',
#    'patterns': ['yeah  a couple  we are outnumbered by the cows though'],
#    'responses': ['how many people were in your old school'],
#    'context_set': ''},
#   {'tag': '95',
#    'patterns': ['get out'],
#    'responses': ['how many people go here'],
#    'context_set': ''},
#   {'tag': '96',
#    'patterns': ['how many people go here'],
#    'responses': ['couple thousand most of them evil'],
#    'context_set': ''},
#   {'tag': '97',
#    'patterns': ['that i am used to'],
#    'responses': ['yeah but these guys have never seen a horse  they just jack off to clint eastwood'],
#    'context_set': ''},
#   {'tag': '98',
#    'patterns': ['that girl  i '],
#    'responses': ['you burn you pine you perish'],
#    'context_set': ''},
#   {'tag': '99',
#    'patterns': ['you burn you pine you perish'],
#    'responses': ['who is she'],
#    'context_set': ''},
#   {'tag': '100',
#    'patterns': ['who is she'],
#    'responses': ['bianca stratford  sophomore do not even think about it'],
#    'context_set': ''},
#   {'tag': '101',
#    'patterns': ['bianca stratford  sophomore do not even think about it'],
#    'responses': ['why not'],
#    'context_set': ''},
#   {'tag': '102',
#    'patterns': ['why do girls like that always like guys like that'],
#    'responses': ['because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted'],
#    'context_set': ''},
#   {'tag': '103',
#    'patterns': ['because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted'],
#    'responses': ['he always have that shiteating grin'],
#    'context_set': ''},
#   {'tag': '104',
#    'patterns': ['you know french'],
#    'responses': ["sure do  my mom's from canada"],
#    'context_set': ''},
#   {'tag': '105',
#    'patterns': ["sure do  my mom's from canada"],
#    'responses': ['guess who just signed up for a tutor'],
#    'context_set': ''},
#   {'tag': '106',
#    'patterns': ['guess who just signed up for a tutor'],
#    'responses': ['you mean i would get a chance to talk to her'],
#    'context_set': ''},
#   {'tag': '107',
#    'patterns': ['you mean i would get a chance to talk to her'],
#    'responses': ['you could consecrate with her my friend'],
#    'context_set': ''},
#   {'tag': '108',
#    'patterns': ['yeah just a minor encounter with the shrew'],
#    'responses': ["that is her  bianca's sister"],
#    'context_set': ''},
#   {'tag': '109',
#    'patterns': ["that is her  bianca's sister"],
#    'responses': ['the mewling rampalian wretch herself'],
#    'context_set': ''},
#   {'tag': '110',
#    'patterns': ['i teach her french get to know her dazzle her with charm and she falls in love with me'],
#    'responses': ['unlikely but even so she still ca not go out with you  so what is the point'],
#    'context_set': ''},
#   {'tag': '111',
#    'patterns': ['what about him'],
#    'responses': ['you wanna go out with him'],
#    'context_set': ''},
#   {'tag': '112',
#    'patterns': ['what makes you think he will do it'],
#    'responses': ['he seems like he thrives on danger'],
#    'context_set': ''},
#   {'tag': '113',
#    'patterns': ['he seems like he thrives on danger'],
#    'responses': ['no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz'],
#    'context_set': ''},
#   {'tag': '114',
#    'patterns': ['no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz'],
#    'responses': ['they always let felons sit in on honors biology'],
#    'context_set': ''},
#   {'tag': '115',
#    'patterns': ['they always let felons sit in on honors biology'],
#    'responses': ['i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers'],
#    'context_set': ''},
#   {'tag': '116',
#    'patterns': ['i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers'],
#    'responses': ['forget his reputation  do you think we have got a plan or not'],
#    'context_set': ''},
#   {'tag': '117',
#    'patterns': ['forget his reputation  do you think we have got a plan or not'],
#    'responses': ['did she actually say she would go out with you'],
#    'context_set': ''},
#   {'tag': '118',
#    'patterns': ['did she actually say she would go out with you'],
#    'responses': ['that is what i just said'],
#    'context_set': ''},
#   {'tag': '119',
#    'patterns': ['you know if you do go out with bianca you would be set  you would outrank everyone strictly alist  with me by your side'],
#    'responses': ['i thought you hated those people'],
#    'context_set': ''},
#   {'tag': '120',
#    'patterns': ['i thought you hated those people'],
#    'responses': ['hey  i have gotta have a few clients when i get to wall street'],
#    'context_set': ''},
#   {'tag': '121',
#    'patterns': ['this is it  a golden opportunity patrick can ask katarina to the party'],
#    'responses': ['in that case we will need to make it a schoolwide blow out'],
#    'context_set': ''},
#   {'tag': '122',
#    'patterns': ['in that case we will need to make it a schoolwide blow out'],
#    'responses': ['will bogey get bent'],
#    'context_set': ''},
#   {'tag': '123',
#    'patterns': ['will bogey get bent'],
#    'responses': ['are you kidding  he will piss himself with joy  he is the ultimate kiss ass'],
#    'context_set': ''},
#   {'tag': '124',
#    'patterns': ['number one  she hates smokers'],
#    'responses': ["it's a lung cancer issue"],
#    'context_set': ''},
#   {'tag': '125',
#    'patterns': ["it's a lung cancer issue"],
#    'responses': ['her favorite uncle'],
#    'context_set': ''},
#   {'tag': '126',
#    'patterns': ['her favorite uncle'],
#    'responses': ['dead at fortyone'],
#    'context_set': ''},
#   {'tag': '127',
#    'patterns': ['he is pretty'],
#    'responses': ['okay  i was not sure'],
#    'context_set': ''},
#   {'tag': '128',
#    'patterns': ['assail your ears for one night'],
#    'responses': ["it's her favorite band"],
#    'context_set': ''},
#   {'tag': '129',
#    'patterns': ['you told me that part already'],
#    'responses': ['hell i have just been going over the whole thing in my head and '],
#    'context_set': ''},
#   {'tag': '130',
#    'patterns': ['extremely unfortunate maneuver'],
#    'responses': ["the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her"],
#    'context_set': ''},
#   {'tag': '131',
#    'patterns': ["the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her"],
#    'responses': ['buttholus extremus  but hey you are making progress'],
#    'context_set': ''},
#   {'tag': '132',
#    'patterns': ['buttholus extremus  but hey you are making progress'],
#    'responses': ["no i ' m not"],
#    'context_set': ''},
#   {'tag': '133',
#    'patterns': ['you humiliated the woman sacrifice yourself on the altar of dignity and even the score'],
#    'responses': ['best case scenario you are back on the payroll for awhile'],
#    'context_set': ''},
#   {'tag': '134',
#    'patterns': ['and he means that strictly in a non prisonmovie type of way'],
#    'responses': ['yeah  we will see'],
#    'context_set': ''},
#   {'tag': '135',
#    'patterns': ['what have you got for me'],
#    'responses': ['i have retrieved certain pieces of information on miss katarina stratford i think you will find helpful'],
#    'context_set': ''},
#   {'tag': '136',
#    'patterns': ['gigglepuss is playing there tomorrow night'],
#    'responses': ['do not make me do it man'],
#    'context_set': ''},
#   {'tag': '137',
#    'patterns': ['cameron i am a little busy'],
#    'responses': ["it's off the whole thing"],
#    'context_set': ''},
#   {'tag': '138',
#    'patterns': ['what  are you talking about'],
#    'responses': ['she is partial to joey not me'],
#    'context_set': ''},
#   {'tag': '139',
#    'patterns': ['what would you do to her'],
#    'responses': ["i don ' t know  i decided not to nail her when she was too drunk to remember it"],
#    'context_set': ''},
#   {'tag': '140',
#    'patterns': ['she hates you with the fire of a thousand suns   that is a direct quote'],
#    'responses': ['she just needs time to cool off i will give it a day'],
#    'context_set': ''},
#   {'tag': '141',
#    'patterns': ["you makin' any headway"],
#    'responses': ['she kissed me'],
#    'context_set': ''},
#   {'tag': '142',
#    'patterns': ['what is the worst'],
#    'responses': ['you get the girl'],
#    'context_set': ''},
#   {'tag': '143',
#    'patterns': ['the vintage look is over kat have not you been reading your sassy'],
#    'responses': ['yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break'],
#    'context_set': ''},
#   {'tag': '144',
#    'patterns': ['yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break'],
#    'responses': ['they are running the rest of me next month'],
#    'context_set': ''},
#   {'tag': '145',
#    'patterns': ['hey  do you mind'],
#    'responses': ['not at all'],
#    'context_set': ''},
#   {'tag': '146',
#    'patterns': ['leave my sister alone'],
#    'responses': ['and why would i do that'],
#    'context_set': ''},
#   {'tag': '147',
#    'patterns': ['two legs nice rack'],
#    'responses': ['yeah whatever  i want you to go out with her'],
#    'context_set': ''},
#   {'tag': '148',
#    'patterns': ['yeah whatever  i want you to go out with her'],
#    'responses': ['sure sparky  i will get right on it'],
#    'context_set': ''},
#   {'tag': '149',
#    'patterns': ['sure sparky  i will get right on it'],
#    'responses': ['you just said'],
#    'context_set': ''},
#   {'tag': '150',
#    'patterns': ['you just said'],
#    'responses': ['you need money to take a girl out'],
#    'context_set': ''},
#   {'tag': '151',
#    'patterns': ['you need money to take a girl out'],
#    'responses': ['but you would go out with her if you had the cake'],
#    'context_set': ''},
#   {'tag': '152',
#    'patterns': ['you got it verona  i pick up the tab you do the honors'],
#    'responses': ['you are gonna pay me to take out some girl'],
#    'context_set': ''},
#   {'tag': '153',
#    'patterns': ['you are gonna pay me to take out some girl'],
#    'responses': ['i ca not date her sister until that one gets a boyfriend  and that is the catch she does not want a boyfriend'],
#    'context_set': ''},
#   {'tag': '154',
#    'patterns': ['i ca not date her sister until that one gets a boyfriend  and that is the catch she does not want a boyfriend'],
#    'responses': ['how much'],
#    'context_set': ''},
#   {'tag': '155',
#    'patterns': ['i ca not take a girl like that out on twenty bucks'],
#    'responses': ['fine thirty'],
#    'context_set': ''},
#   {'tag': '156',
#    'patterns': ['take it or leave it  this is not a negotiation'],
#    'responses': ['fifty and you have got your man'],
#    'context_set': ''},
#   {'tag': '157',
#    'patterns': ['when i shell out fifty i expect results'],
#    'responses': ['i am on it'],
#    'context_set': ''},
#   {'tag': '158',
#    'patterns': ['i am on it'],
#    'responses': ['watching the bitch trash my car does not count as a date'],
#    'context_set': ''},
#   {'tag': '159',
#    'patterns': ['watching the bitch trash my car does not count as a date'],
#    'responses': ['i got her under control she just acts crazed in public to keep up the image'],
#    'context_set': ''},
#   {'tag': '160',
#    'patterns': ['a hundred bucks a date'],
#    'responses': ['forget it'],
#    'context_set': ''},
#   {'tag': '161',
#    'patterns': ['forget it'],
#    'responses': ['forget her sister then'],
#    'context_set': ''},
#   {'tag': '162',
#    'patterns': ["it's about time"],
#    'responses': ["a deal's a deal"],
#    'context_set': ''},
#   {'tag': '163',
#    'patterns': ['how would you do it'],
#    'responses': ['do what'],
#    'context_set': ''},
#   {'tag': '164',
#    'patterns': ['do what'],
#    'responses': ['get her to act like a human'],
#    'context_set': ''},
#   {'tag': '165',
#    'patterns': ['i do not know dorsey the limothe flowers  another hundred for the tux '],
#    'responses': ["enough with the barbie n' ken shit i know"],
#    'context_set': ''},
#   {'tag': '166',
#    'patterns': ['are you lost'],
#    'responses': ['nope  just came by to chat'],
#    'context_set': ''},
#   {'tag': '167',
#    'patterns': ['nope  just came by to chat'],
#    'responses': ['we do not chat'],
#    'context_set': ''},
#   {'tag': '168',
#    'patterns': ['we do not chat'],
#    'responses': ['well actually i thought i would run an idea by you  you know just to see if you are interested'],
#    'context_set': ''},
#   {'tag': '169',
#    'patterns': ['well actually i thought i would run an idea by you  you know just to see if you are interested'],
#    'responses': ['we are not'],
#    'context_set': ''},
#   {'tag': '170',
#    'patterns': ['but she ca not go out with you because her sister is this insane head case and no one will go out with her right'],
#    'responses': ['does this conversation have a purpose'],
#    'context_set': ''},
#   {'tag': '171',
#    'patterns': ['does this conversation have a purpose'],
#    'responses': ["so what you need to do is recruit a guy who will go out with her  someone who's up for the job"],
#    'context_set': ''},
#   {'tag': '172',
#    'patterns': ["i hear you are helpin' verona"],
#    'responses': ['uh  yeah  we are old friend*'],
#    'context_set': ''},
#   {'tag': '173',
#    'patterns': ['uh  yeah  we are old friend*'],
#    'responses': ['you and verona'],
#    'context_set': ''},
#   {'tag': '174',
#    'patterns': ['you and verona'],
#    'responses': ['what  we took bathes together when we were kids'],
#    'context_set': ''},
#   {'tag': '175',
#    'patterns': ['you better not fuck this up  i am heavily invested'],
#    'responses': ["hey  it's all for the higher good right"],
#    'context_set': ''},
#   {'tag': '176',
#    'patterns': ["who's that"],
#    'responses': ['patrick verona   random skid'],
#    'context_set': ''},
#   {'tag': '177',
#    'patterns': ['patrick verona   random skid'],
#    'responses': ['that is pat verona the one who was gone for a year i heard he was doing porn movies'],
#    'context_set': ''},
#   {'tag': '178',
#    'patterns': ['that is pat verona the one who was gone for a year i heard he was doing porn movies'],
#    'responses': ['i am sure he is completely incapable of doing anything that interesting'],
#    'context_set': ''},
#   {'tag': '179',
#    'patterns': ['i am sure he is completely incapable of doing anything that interesting'],
#    'responses': ['he always look so'],
#    'context_set': ''},
#   {'tag': '180',
#    'patterns': ['he always look so'],
#    'responses': ['block e'],
#    'context_set': ''},
#   {'tag': '181',
#    'patterns': ['mandella eat  starving yourself is a very slow way to die'],
#    'responses': ['just a little'],
#    'context_set': ''},
#   {'tag': '182',
#    'patterns': ['what is this'],
#    'responses': ['an attempted slit'],
#    'context_set': ''},
#   {'tag': '183',
#    'patterns': ['the people at this school are so incredibly foul'],
#    'responses': ['you could always go with me  i am sure william has some friends'],
#    'context_set': ''},
#   {'tag': '184',
#    'patterns': ['william would never have gone to a state school'],
#    'responses': ['william did not even go to high school'],
#    'context_set': ''},
#   {'tag': '185',
#    'patterns': ['william did not even go to high school'],
#    'responses': ['that is never been proven'],
#    'context_set': ''},
#   {'tag': '186',
#    'patterns': ['that is never been proven'],
#    'responses': ['neither has his heterosexuality'],
#    'context_set': ''},
#   {'tag': '187',
#    'patterns': ['i appreciate your efforts toward a speedy death but i am consuming  do you mind'],
#    'responses': ['does it matter'],
#    'context_set': ''},
#   {'tag': '188',
#    'patterns': ['does it matter'],
#    'responses': ['if i was bianca it would be any school you want precious  do not forget your tiara'],
#    'context_set': ''},
#   {'tag': '189',
#    'patterns': ['you think this will work'],
#    'responses': ['no fear'],
#    'context_set': ''},
#   {'tag': '190',
#    'patterns': ['what would he say'],
#    'responses': ['who cares'],
#    'context_set': ''},
#   {'tag': '191',
#    'patterns': ['you went to the party  i thought we were officially opposed to suburban social activity'],
#    'responses': ['i did not have a choice'],
#    'context_set': ''},
#   {'tag': '192',
#    'patterns': ['i did not have a choice'],
#    'responses': ['you did not have a choice  where is kat and what have you done with her'],
#    'context_set': ''},
#   {'tag': '193',
#    'patterns': ['you did not have a choice  where is kat and what have you done with her'],
#    'responses': ['i did bianca a favor and it backfired'],
#    'context_set': ''},
#   {'tag': '194',
#    'patterns': ['i did bianca a favor and it backfired'],
#    'responses': ['you did not'],
#    'context_set': ''},
#   {'tag': '195',
#    'patterns': ['you did not'],
#    'responses': ['i got drunk  i puked  i got rejected it was big fun'],
#    'context_set': ''},
#   {'tag': '196',
#    'patterns': ['can you even imagine  who the hell would go to this a bastion of commercial excess'],
#    'responses': ['well i guess we are not since we do not have dates '],
#    'context_set': ''},
#   {'tag': '197',
#    'patterns': ['well i guess we are not since we do not have dates '],
#    'responses': ['listen to you  you sound like betty all pissed off because archie is taking veronica'],
#    'context_set': ''},
#   {'tag': '198',
#    'patterns': ['listen to you  you sound like betty all pissed off because archie is taking veronica'],
#    'responses': ["okay okay we wo not go  it's not like i have a dress anyway"],
#    'context_set': ''},
#   {'tag': '199',
#    'patterns': ["okay okay we wo not go  it's not like i have a dress anyway"],
#    'responses': ["you ' re looking at this from the wrong perspective  we are making a statement"],
#    'context_set': ''},
#   {'tag': '200',
#    'patterns': ["you ' re looking at this from the wrong perspective  we are making a statement"],
#    'responses': ['oh good  something new and different for us'],
#    'context_set': ''},
#   {'tag': '201',
#    'patterns': ['william  he asked me to meet him here'],
#    'responses': ["oh honey  tell me we have not' progressed to fullon hallucinations"],
#    'context_set': ''},
#   {'tag': '202',
#    'patterns': ["i mean woman  how ya doin'"],
#    'responses': ['sweating like a pig actually  and yourself'],
#    'context_set': ''},
#   {'tag': '203',
#    'patterns': ['sweating like a pig actually  and yourself'],
#    'responses': ["there's a way to get a guy's attention"],
#    'context_set': ''},
#   {'tag': '204',
#    'patterns': ["there's a way to get a guy's attention"],
#    'responses': ['my mission in life'],
#    'context_set': ''},
#   {'tag': '205',
#    'patterns': ['pick you up friday then'],
#    'responses': ['oh right  friday'],
#    'context_set': ''},
#   {'tag': '206',
#    'patterns': ['the night i take you to places you have never been before  and back'],
#    'responses': ['like where  the 7eleven on burnside do you even know my name screwboy'],
#    'context_set': ''},
#   {'tag': '207',
#    'patterns': ['like where  the 7eleven on burnside do you even know my name screwboy'],
#    'responses': ['i know a lot more than that'],
#    'context_set': ''},
#   {'tag': '208',
#    'patterns': ['you hate me do not you'],
#    'responses': ['i do not really think you warrant that strong an emotion'],
#    'context_set': ''},
#   {'tag': '209',
#    'patterns': ['i do not really think you warrant that strong an emotion'],
#    'responses': ['then say you will spend dollar night at the track with me'],
#    'context_set': ''},
#   {'tag': '210',
#    'patterns': ['then say you will spend dollar night at the track with me'],
#    'responses': ['and why would i do that'],
#    'context_set': ''},
#   {'tag': '211',
#    'patterns': ['and why would i do that'],
#    'responses': ['come on  the ponies the flat beer you with money in your eyes me with my hand on your ass'],
#    'context_set': ''},
#   {'tag': '212',
#    'patterns': ['come on  the ponies the flat beer you with money in your eyes me with my hand on your ass'],
#    'responses': ['you  covered in my vomit'],
#    'context_set': ''},
#   {'tag': '213',
#    'patterns': ['are you following me'],
#    'responses': ['i was in the laundromat i saw your car thought i would say hi'],
#    'context_set': ''},
#   {'tag': '214',
#    'patterns': ['you are not a big talker are you'],
#    'responses': ['depends on the topic my fenders do not really whip me into a verbal frenzy'],
#    'context_set': ''},
#   {'tag': '215',
#    'patterns': ['excuse me'],
#    'responses': ['that is what you want is not it'],
#    'context_set': ''},
#   {'tag': '216',
#    'patterns': ['that is what you want is not it'],
#    'responses': ['do you mind  you are sort of ruining it for me'],
#    'context_set': ''},
#   {'tag': '217',
#    'patterns': ['you know these guys are no bikini kill or the raincoats but they are right up there'],
#    'responses': ['you know who the raincoats are'],
#    'context_set': ''},
#   {'tag': '218',
#    'patterns': ['you know who the raincoats are'],
#    'responses': ['why do not you'],
#    'context_set': ''},
#   {'tag': '219',
#    'patterns': ['what is this'],
#    'responses': ['i am getting trashed man is not that what you are supposed to do at a party'],
#    'context_set': ''},
#   {'tag': '220',
#    'patterns': ['i am getting trashed man is not that what you are supposed to do at a party'],
#    'responses': ['i say do what you wanna do'],
#    'context_set': ''},
#   {'tag': '221',
#    'patterns': ['i say do what you wanna do'],
#    'responses': ['funny you are the only one'],
#    'context_set': ''},
#   {'tag': '222',
#    'patterns': ['you are not okay'],
#    'responses': ['i just need to lie down for awhile'],
#    'context_set': ''},
#   {'tag': '223',
#    'patterns': ['i just need to lie down for awhile'],
#    'responses': ['uh uh you lie down and you will go to sleep'],
#    'context_set': ''},
#   {'tag': '224',
#    'patterns': ['uh uh you lie down and you will go to sleep'],
#    'responses': ['i know just let me sleep'],
#    'context_set': ''},
#   {'tag': '225',
#    'patterns': ['this is so patronizing'],
#    'responses': ['leave it to you to use big words when you are shitfaced'],
#    'context_set': ''},
#   {'tag': '226',
#    'patterns': ['leave it to you to use big words when you are shitfaced'],
#    'responses': ['why  are you doing this'],
#    'context_set': ''},
#   {'tag': '227',
#    'patterns': ['why  are you doing this'],
#    'responses': ['i told you'],
#    'context_set': ''},
#   {'tag': '228',
#    'patterns': ['i told you'],
#    'responses': ['you do not care if i die'],
#    'context_set': ''},
#   {'tag': '229',
#    'patterns': ['you do not care if i die'],
#    'responses': ['sure i do'],
#    'context_set': ''},
#   {'tag': '230',
#    'patterns': ['because then i would have to start taking out girls who like me'],
#    'responses': ['like you could find one'],
#    'context_set': ''},
#   {'tag': '231',
#    'patterns': ['like you could find one'],
#    'responses': ['see that  who needs affection when i have got blind hatred'],
#    'context_set': ''},
#   {'tag': '232',
#    'patterns': ['see that  who needs affection when i have got blind hatred'],
#    'responses': ['just let me sit down'],
#    'context_set': ''},
#   {'tag': '233',
#    'patterns': ['i hate him'],
#    'responses': ['i know  it would have to be a pretty big deal to get you to mainline tequila you do not seem like the type'],
#    'context_set': ''},
#   {'tag': '234',
#    'patterns': ['i know  it would have to be a pretty big deal to get you to mainline tequila you do not seem like the type'],
#    'responses': ["hey man    you don ' t think i can be cool  you do not think i can be laid back like everyone else"],
#    'context_set': ''},
#   {'tag': '235',
#    'patterns': ["hey man    you don ' t think i can be cool  you do not think i can be laid back like everyone else"],
#    'responses': ['i thought you were above all that'],
#    'context_set': ''},
#   {'tag': '236',
#    'patterns': ['i thought you were above all that'],
#    'responses': ['you know what they say'],
#    'context_set': ''},
#   {'tag': '237',
#    'patterns': ['and i am in control of it'],
#    'responses': ["but it's gigglepuss  i know you like them  i saw you there"],
#    'context_set': ''},
#   {'tag': '238',
#    'patterns': ['no you were not'],
#    'responses': ['then why would you ask'],
#    'context_set': ''},
#   {'tag': '239',
#    'patterns': ['then why would you ask'],
#    'responses': ['why would you lie'],
#    'context_set': ''},
#   {'tag': '240',
#    'patterns': ['i should do this'],
#    'responses': ['do what'],
#    'context_set': ''},
#   {'tag': '241',
#    'patterns': ['start a band'],
#    'responses': ['my father would not approve of that that'],
#    'context_set': ''},
#   {'tag': '242',
#    'patterns': ['my father would not approve of that that'],
#    'responses': ['you do not strike me as the type that would ask permission'],
#    'context_set': ''},
#   {'tag': '243',
#    'patterns': ['oh so now you think you know me'],
#    'responses': ["i am gettin' there"],
#    'context_set': ''},
#   {'tag': '244',
#    'patterns': ["so what ' s up with your dad  he a pain in the ass"],
#    'responses': ['he just wants me to be someone i am not'],
#    'context_set': ''},
#   {'tag': '245',
#    'patterns': ['excuse me have you seen the feminine mystique  i lost my copy'],
#    'responses': ['what are you doing here'],
#    'context_set': ''},
#   {'tag': '246',
#    'patterns': ['what are you doing here'],
#    'responses': ['i heard there was a poetry reading'],
#    'context_set': ''},
#   {'tag': '247',
#    'patterns': ['i heard there was a poetry reading'],
#    'responses': ['you  are so '],
#    'context_set': ''},
#   {'tag': '248',
#    'patterns': ['unwelcome  i guess someone still has her panties in a twist'],
#    'responses': ['do not for one minute think that you had any effect whatsoever on my panties'],
#    'context_set': ''},
#   {'tag': '249',
#    'patterns': ['do not for one minute think that you had any effect whatsoever on my panties'],
#    'responses': ['so what did i have an effect on '],
#    'context_set': ''},
#   {'tag': '250',
#    'patterns': ['so what did i have an effect on '],
#    'responses': ['other than my upchuck reflex nothing'],
#    'context_set': ''},
#   {'tag': '251',
#    'patterns': ['he left  i sprung the dickhead and he cruised on me'],
#    'responses': ['look up sunshine'],
#    'context_set': ''},
#   {'tag': '252',
#    'patterns': ['i guess i never told you i am afraid of heights'],
#    'responses': ["c'mon  it's not that bad"],
#    'context_set': ''},
#   {'tag': '253',
#    'patterns': ["c'mon  it's not that bad"],
#    'responses': ["try lookin' at it from this angle"],
#    'context_set': ''},
#   {'tag': '254',
#    'patterns': ['put your right foot there '],
#    'responses': ["forget it  i am stayin'"],
#    'context_set': ''},
#   {'tag': '255',
#    'patterns': ["forget it  i am stayin'"],
#    'responses': ['you want me to climb up and show you how to get down'],
#    'context_set': ''},
#   {'tag': '256',
#    'patterns': ['the partridge family'],
#    'responses': ['i figured it had to be something ridiculous to win your respect  and piss you off'],
#    'context_set': ''},
#   {'tag': '257',
#    'patterns': ['i figured it had to be something ridiculous to win your respect  and piss you off'],
#    'responses': ['good call'],
#    'context_set': ''},
#   {'tag': '258',
#    'patterns': ['good call'],
#    'responses': ['so how would you get chapin to look the other way'],
#    'context_set': ''},
#   {'tag': '259',
#    'patterns': ['so how would you get chapin to look the other way'],
#    'responses': ['i dazzled him with my wit'],
#    'context_set': ''},
#   {'tag': '260',
#    'patterns': ['a soft side who knew'],
#    'responses': ['yeah well do not let it get out'],
#    'context_set': ''},
#   {'tag': '261',
#    'patterns': ['yeah well do not let it get out'],
#    'responses': ['so what is your excuse'],
#    'context_set': ''},
#   {'tag': '262',
#    'patterns': ['so what is your excuse'],
#    'responses': ['acting the way we do'],
#    'context_set': ''},
#   {'tag': '263',
#    'patterns': ['i do not like to do what people expect then they expect it all the time and they get disappointed when you change'],
#    'responses': ['so if you disappoint them from the start you are covered'],
#    'context_set': ''},
#   {'tag': '264',
#    'patterns': ['so if you disappoint them from the start you are covered'],
#    'responses': ['something like that'],
#    'context_set': ''},
#   {'tag': '265',
#    'patterns': ['something like that'],
#    'responses': ['then you screwed up'],
#    'context_set': ''},
#   {'tag': '266',
#    'patterns': ['tell me something true'],
#    'responses': ['i hate peas'],
#    'context_set': ''},
#   {'tag': '267',
#    'patterns': ['i hate peas'],
#    'responses': ['no  something real  something no one else knows'],
#    'context_set': ''},
#   {'tag': '268',
#    'patterns': ['no  something real  something no one else knows'],
#    'responses': ['you are sweet  and sexy  and completely hot for me'],
#    'context_set': ''},
#   {'tag': '269',
#    'patterns': ['no one else knows'],
#    'responses': ['you are amazingly selfassured has anyone ever told you that'],
#    'context_set': ''},
#   {'tag': '270',
#    'patterns': ['you are amazingly selfassured has anyone ever told you that'],
#    'responses': ['go to the prom with me'],
#    'context_set': ''},
#   {'tag': '271',
#    'patterns': ['is that a request or a command'],
#    'responses': ['you know what i mean'],
#    'context_set': ''},
#   {'tag': '272',
#    'patterns': ['no what'],
#    'responses': ['no i wo not go with you'],
#    'context_set': ''},
#   {'tag': '273',
#    'patterns': ['no i wo not go with you'],
#    'responses': ['why not'],
#    'context_set': ''},
#   {'tag': '274',
#    'patterns': ['why not'],
#    'responses': ["because i do not want to it's a stupid tradition"],
#    'context_set': ''},
#   {'tag': '275',
#    'patterns': ['create a little drama  start a new rumor  what'],
#    'responses': ['so i have to have a motive to be with you'],
#    'context_set': ''},
#   {'tag': '276',
#    'patterns': ['so i have to have a motive to be with you'],
#    'responses': ['you tell me'],
#    'context_set': ''},
#   {'tag': '277',
#    'patterns': ['you tell me'],
#    'responses': ['you need therapy  has anyone ever told you that'],
#    'context_set': ''},
#   {'tag': '278',
#    'patterns': ['you need therapy  has anyone ever told you that'],
#    'responses': ['answer the question patrick'],
#    'context_set': ''},
#   {'tag': '279',
#    'patterns': ['answer the question patrick'],
#    'responses': ["nothing  there's nothing in it for me just the pleasure of your company"],
#    'context_set': ''},
#   {'tag': '280',
#    'patterns': ['how would you get a tux at the last minute'],
#    'responses': ["it's scurvy's  his date got convicted where would you get the dress"],
#    'context_set': ''},
#   {'tag': '281',
#    'patterns': ["it's scurvy's  his date got convicted where would you get the dress"],
#    'responses': ["it's just something i had  you know"],
#    'context_set': ''},
#   {'tag': '282',
#    'patterns': ["it's just something i had  you know"],
#    'responses': ['oh huh'],
#    'context_set': ''},
#   {'tag': '283',
#    'patterns': ['oh huh'],
#    'responses': ['look i am   sorry  that i questioned your motives  i was wrong'],
#    'context_set': ''},
#   {'tag': '284',
#    'patterns': ["that ' s completely adorable"],
#    'responses': ['it gets worse  you still have your freshman yearbook'],
#    'context_set': ''},
#   {'tag': '285',
#    'patterns': ['wait i'],
#    'responses': ['you were paid to take me out  by  the one person i truly hate  i knew it was a setup'],
#    'context_set': ''},
#   {'tag': '286',
#    'patterns': ['you were paid to take me out  by  the one person i truly hate  i knew it was a setup'],
#    'responses': ['it was not like that'],
#    'context_set': ''},
#   {'tag': '287',
#    'patterns': ['it was not like that'],
#    'responses': ['really  what was it like  a down payment now then a bonus for sleeping with me'],
#    'context_set': ''},
#   {'tag': '288',
#    'patterns': ['really  what was it like  a down payment now then a bonus for sleeping with me'],
#    'responses': ['i did not care about the money'],
#    'context_set': ''},
#   {'tag': '289',
#    'patterns': ['a fender strat you bought this'],
#    'responses': ['i thought you could use it when you start your band'],
#    'context_set': ''},
#   {'tag': '290',
#    'patterns': ['besides i had some extra cash some asshole paid me to take out a really great girl'],
#    'responses': ['is that right'],
#    'context_set': ''},
#   {'tag': '291',
#    'patterns': ['is that right'],
#    'responses': ['yeah but then i fucked up i fell for her'],
#    'context_set': ''},
# ...
#    'responses': ['you are kidding'],
#    'context_set': ''},
#   {'tag': '911',
#    'patterns': ['i do not know hal said he thought it might be the assembly procedure'],
#    'responses': ['two units in four days how many spares do we have'],
#    'context_set': ''},
#   {'tag': '912',
#    'patterns': ['two units in four days how many spares do we have'],
#    'responses': ['two more'],
#    'context_set': ''},
#   {'tag': '913',
#    'patterns': ['two more'],
#    'responses': ["well i hope there's nothing wrong with the assembly on those other wise we are out of business"],
#    'context_set': ''},
#   {'tag': '914',
#    'patterns': ["it's the last one"],
#    'responses': ['well now that we have got one that is actually failed we should be able to figure out what is happened and fix it'],
#    'context_set': ''},
#   {'tag': '915',
#    'patterns': ['i did not do that frank i took particular care not to freeze them'],
#    'responses': ['i guess you do not know your own strength old boy'],
#    'context_set': ''},
#   {'tag': '916',
#    'patterns': ['i guess you do not know your own strength old boy'],
#    'responses': ['i guess not'],
#    'context_set': ''},
#   {'tag': '917',
#    'patterns': ['i guess not'],
#    'responses': ['i think i will have to go out and burn them off'],
#    'context_set': ''},
#   {'tag': '918',
#    'patterns': ['i am sorry frank but i do not think i can answer that question without knowing everything that all of you know'],
#    'responses': ['he is got a point'],
#    'context_set': ''},
#   {'tag': '919',
#    'patterns': ['sorry to interrupt the festivities dave but i think we have got a problem'],
#    'responses': ['what is it hal'],
#    'context_set': ''},
#   {'tag': '920',
#    'patterns': ['what is it hal'],
#    'responses': ['my fpc shows an impending failure of the antenna orientation unit'],
#    'context_set': ''},
#   {'tag': '921',
#    'patterns': ['the unit is still operational dave but it will fail within seventytwo hours'],
#    'responses': ['i understand hal we will take care of it please let me have the hard copy'],
#    'context_set': ''},
#   {'tag': '922',
#    'patterns': ['not now hal i would like to talk to you about something'],
#    'responses': ['sure dave what is up'],
#    'context_set': ''},
#   {'tag': '923',
#    'patterns': ['sure dave what is up'],
#    'responses': ['you know that we checked the two aounits that you reported in imminent failure condition'],
#    'context_set': ''},
#   {'tag': '924',
#    'patterns': ['you know that we checked the two aounits that you reported in imminent failure condition'],
#    'responses': ['yes i know'],
#    'context_set': ''},
#   {'tag': '925',
#    'patterns': ['yes i know'],
#    'responses': ['you probably also know that we found them okay'],
#    'context_set': ''},
#   {'tag': '926',
#    'patterns': ['you probably also know that we found them okay'],
#    'responses': ['yes i know that but i can assure you that they were about to fail'],
#    'context_set': ''},
#   {'tag': '927',
#    'patterns': ["i am not questioning your word dave but it's just not possible i am not capable of being wrong"],
#    'responses': ['hal is there anything bothering you  anything that might account for this problem'],
#    'context_set': ''},
#   {'tag': '928',
#    'patterns': ['i am sorry about the misunderstanding hal'],
#    'responses': ['well do not worry about it'],
#    'context_set': ''},
#   {'tag': '929',
#    'patterns': ['well do not worry about it'],
#    'responses': ['and do not you worry about it'],
#    'context_set': ''},
#   {'tag': '930',
#    'patterns': ['and do not you worry about it'],
#    'responses': ['is your confidence in me fully restored'],
#    'context_set': ''},
#   {'tag': '931',
#    'patterns': ['is your confidence in me fully restored'],
#    'responses': ['yes it is hal'],
#    'context_set': ''},
#   {'tag': '932',
#    'patterns': ['yes it is hal'],
#    'responses': ['well that is a relief you know i have the greatest enthusiasm possible for the mission'],
#    'context_set': ''},
#   {'tag': '933',
#    'patterns': ['too bad about frank is not it'],
#    'responses': ['yes it is'],
#    'context_set': ''},
#   {'tag': '934',
#    'patterns': ['yes it is'],
#    'responses': ['i suppose you are pretty broken up about it'],
#    'context_set': ''},
#   {'tag': '935',
#    'patterns': ['the antenna has to be replaced'],
#    'responses': ['repairing the antenna is a pretty dangerous operation'],
#    'context_set': ''},
#   {'tag': '936',
#    'patterns': ['repairing the antenna is a pretty dangerous operation'],
#    'responses': ["it does not have to be hal it's more dangerous to be out of touch with earth let me have manual control please"],
#    'context_set': ''},
#   {'tag': '937',
#    'patterns': ["it does not have to be hal it's more dangerous to be out of touch with earth let me have manual control please"],
#    'responses': ['i do not really agree with you dave my onboard memory store is more than capable of handling all the mission requirements'],
#    'context_set': ''},
#   {'tag': '938',
#    'patterns': ["if you are determined to revive the crew now i can handle the whole thing myself there's no need for you to trouble"],
#    'responses': ['i am goin to do this myself hal let me have the control please'],
#    'context_set': ''},
#   {'tag': '939',
#    'patterns': ['i am goin to do this myself hal let me have the control please'],
#    'responses': ['look dave your have probably got a lot to do i suggest you leave it to me'],
#    'context_set': ''},
#   {'tag': '940',
#    'patterns': ['look dave your have probably got a lot to do i suggest you leave it to me'],
#    'responses': ['hal switch to manual hibernation control'],
#    'context_set': ''},
#   {'tag': '941',
#    'patterns': ['i am at space station five darling how are you'],
#    'responses': ['i am fine daddy when are you coming home'],
#    'context_set': ''},
#   {'tag': '942',
#    'patterns': ['i am having a party tomorrow'],
#    'responses': ['yes i know that sweetheart'],
#    'context_set': ''},
#   {'tag': '943',
#    'patterns': ['yes i know that sweetheart'],
#    'responses': ['are you coming to my party'],
#    'context_set': ''},
#   {'tag': '944',
#    'patterns': ['are you coming to my party'],
#    'responses': ['no i am sorry darling i told you i wo not be home for a few days'],
#    'context_set': ''},
#   {'tag': '945',
#    'patterns': ['no i am sorry darling i told you i wo not be home for a few days'],
#    'responses': ['when are you coming home'],
#    'context_set': ''},
#   {'tag': '946',
#    'patterns': ['when are you coming home'],
#    'responses': ['in three days darling i hope'],
#    'context_set': ''},
#   {'tag': '947',
#    'patterns': ['one two three can i speak to mommy'],
#    'responses': ["mommy's out to the hair dresser"],
#    'context_set': ''},
#   {'tag': '948',
#    'patterns': ["mommy's out to the hair dresser"],
#    'responses': ['where is mrs brown'],
#    'context_set': ''},
#   {'tag': '949',
#    'patterns': ['where is mrs brown'],
#    'responses': ['she is in the bathroom'],
#    'context_set': ''},
#   {'tag': '950',
#    'patterns': ['she is in the bathroom'],
#    'responses': ['okay sweetheart well i have to go now tell mommy that i called'],
#    'context_set': ''},
#   {'tag': '951',
#    'patterns': ['okay sweetheart well i have to go now tell mommy that i called'],
#    'responses': ['how many days until you come home'],
#    'context_set': ''},
#   {'tag': '952',
#    'patterns': ['how many days until you come home'],
#    'responses': ['three darling one two  three be sure to tell mommy i called'],
#    'context_set': ''},
#   {'tag': '953',
#    'patterns': ['okay sweetheart have a lovely birthday party tomorrow'],
#    'responses': ['thank you daddy'],
#    'context_set': ''},
#   {'tag': '954',
#    'patterns': ['thank you daddy'],
#    'responses': ['i will wish you a happy birthday now and i will see you soon all right darling'],
#    'context_set': ''},
#   {'tag': '955',
#    'patterns': ['i will wish you a happy birthday now and i will see you soon all right darling'],
#    'responses': ['yes daddy'],
#    'context_set': ''},
#   {'tag': '956',
#    'patterns': ['yes daddy'],
#    'responses': ["'bye 'bye now sweetheart"],
#    'context_set': ''},
#   {'tag': '957',
#    'patterns': ["'bye 'bye now sweetheart"],
#    'responses': ['goodbye daddy'],
#    'context_set': ''},
#   {'tag': '958',
#    'patterns': ['oh thank you very much'],
#    'responses': ['thank you'],
#    'context_set': ''},
#   {'tag': '959',
#    'patterns': ['thank you'],
#    'responses': ['well how is it going back there'],
#    'context_set': ''},
#   {'tag': '960',
#    'patterns': ['well i have heard more and more people talk of an epidemic'],
#    'responses': ['i suppose it was bound to happen sooner or later'],
#    'context_set': ''},
#   {'tag': '961',
#    'patterns': ['i suppose it was bound to happen sooner or later'],
#    'responses': ['berkeley told me that they think it came from contamination on a returning mars flight'],
#    'context_set': ''},
#   {'tag': '962',
#    'patterns': ['berkeley told me that they think it came from contamination on a returning mars flight'],
#    'responses': ['yes well whatever it is they are certainly not fooling around this is the first flight they allowed in for more than a week'],
#    'context_set': ''},
#   {'tag': '963',
#    'patterns': ['yes well whatever it is they are certainly not fooling around this is the first flight they allowed in for more than a week'],
#    'responses': ['i was working out what this trip must cost taking him up there by himself and coming back empty'],
#    'context_set': ''},
#   {'tag': '964',
#    'patterns': ['i was working out what this trip must cost taking him up there by himself and coming back empty'],
#    'responses': ["i will bet it's a fortune"],
#    'context_set': ''},
#   {'tag': '965',
#    'patterns': ['and your charming little daughter'],
#    'responses': ['oh she is growing up very fast as a matter of fact she is six tomorrow'],
#    'context_set': ''},
#   {'tag': '966',
#    'patterns': ['oh she is growing up very fast as a matter of fact she is six tomorrow'],
#    'responses': ['oh that is such a delightful age'],
#    'context_set': ''},
#   {'tag': '967',
#    'patterns': ['oh that is such a delightful age'],
#    'responses': ['how is gregor'],
#    'context_set': ''},
#   {'tag': '968',
#    'patterns': ['how is gregor'],
#    'responses': ['he is fine but i am afraid we do not get a chance to see each other very much these days'],
#    'context_set': ''},
#   {'tag': '969',
#    'patterns': ['he is fine but i am afraid we do not get a chance to see each other very much these days'],
#    'responses': ['well where are all of you off to'],
#    'context_set': ''},
#   {'tag': '970',
#    'patterns': ['clavius control came on the air just long enough to transmit their refusal'],
#    'responses': ['well that does sound very odd'],
#    'context_set': ''},
#   {'tag': '971',
#    'patterns': ['are you sure you wo not change your mind about a drink'],
#    'responses': ['no thank you and i am afraid now i really must be going'],
#    'context_set': ''},
#   {'tag': '972',
#    'patterns': ['no thank you and i am afraid now i really must be going'],
#    'responses': ['well i hope that you and your wife can come to the iac conference in june'],
#    'context_set': ''},
#   {'tag': '973',
#    'patterns': ['well gregor and i will look forward to seeing you'],
#    'responses': ["thank you it's been a great pleasure to meet all of you dr smyslov"],
#    'context_set': ''},
#   {'tag': '974',
#    'patterns': ['well thank you very much for being so understanding'],
#    'responses': ['please it really does not matter'],
#    'context_set': ''},
#   {'tag': '975',
#    'patterns': ['please it really does not matter'],
#    'responses': ['well did you have a pleaant flight'],
#    'context_set': ''},
#   {'tag': '976',
#    'patterns': ['well did you have a pleaant flight'],
#    'responses': ['yes very pleasant'],
#    'context_set': ''},
#   {'tag': '977',
#    'patterns': ['yes very pleasant'],
#    'responses': ['well shall we go through documentation'],
#    'context_set': ''},
#   {'tag': '978',
#    'patterns': ['yes i think so just about then'],
#    'responses': ['i suppose you saw the work on our new section while you were docking'],
#    'context_set': ''},
#   {'tag': '979',
#    'patterns': ['i suppose you saw the work on our new section while you were docking'],
#    'responses': ["yes it's coming along very well"],
#    'context_set': ''},
#   {'tag': '980',
#    'patterns': ['are you quite sure'],
#    'responses': ['yes really thank you very much'],
#    'context_set': ''},
#   {'tag': '981',
#    'patterns': ['well as it happens i am on my way up to the moon'],
#    'responses': ['are you by any chance going up to your base at clavius'],
#    'context_set': ''},
#   {'tag': '982',
#    'patterns': ['are you by any chance going up to your base at clavius'],
#    'responses': ['yesas a matter of fact i am'],
#    'context_set': ''},
#   {'tag': '983',
#    'patterns': ['i am sorry but i am not sure i know what you mean'],
#    'responses': ["well it's just for the past two weeks there have been some extremely odd things happening at clavius"],
#    'context_set': ''},
#   {'tag': '984',
#    'patterns': ["yes well at first we thought that was the explanation but it's been going on for the past ten days"],
#    'responses': ['you mean you have not been able to get anyone at the base for ten days'],
#    'context_set': ''},
#   {'tag': '985',
#    'patterns': ['you mean you have not been able to get anyone at the base for ten days'],
#    'responses': ['that is right'],
#    'context_set': ''},
#   {'tag': '986',
#    'patterns': ['that is right'],
#    'responses': ['i see'],
#    'context_set': ''},
#   {'tag': '987',
#    'patterns': ['yes well i hope the crew got back safely'],
#    'responses': ['fortunately they did'],
#    'context_set': ''},
#   {'tag': '988',
#    'patterns': ['fortunately they did'],
#    'responses': ['well i am glad about that'],
#    'context_set': ''},
#   {'tag': '989',
#    'patterns': ['this epidemic could easily spread to our base dr floyd we should be given all the facts'],
#    'responses': ['dr smyslov i am not permitted to discuss this'],
#    'context_set': ''},
#   {'tag': '990',
#    'patterns': ['yes it does the subsurface structure shows that it was deliberately buried about four million years ago'],
#    'responses': ['how can you tell it was deliberately buried'],
#    'context_set': ''},
#   {'tag': '991',
#    'patterns': ['how can you tell it was deliberately buried'],
#    'responses': ['by the deformation between the mother rock and the fill'],
#    'context_set': ''},
#   {'tag': '992',
#    'patterns': ['by the deformation between the mother rock and the fill'],
#    'responses': ['any clue as to what it is'],
#    'context_set': ''},
#   {'tag': '993',
#    'patterns': ['but you do not have any idea as to what it is'],
#    'responses': ['tomb shine surveymarker spare part take your choice'],
#    'context_set': ''},
#   {'tag': '994',
#    'patterns': ['any ideas about the colour'],
#    'responses': ['well not really at first glance black would suggest something sunpowered but then why would anyone deliberately bury a sun powered device'],
#    'context_set': ''},
#   {'tag': '995',
#    'patterns': ['well not really at first glance black would suggest something sunpowered but then why would anyone deliberately bury a sun powered device'],
#    'responses': ['has it been exposed to any sun before now'],
#    'context_set': ''},
#   {'tag': '996',
#    'patterns': ['has it been exposed to any sun before now'],
#    'responses': ['i do not think it has but i would like to check that simpson what is the log on that'],
#    'context_set': ''},
#   {'tag': '997',
#    'patterns': ["oh marvellous it's the first real sleep i have had for the past two days"],
#    'responses': ["there's nothing like weightless sleep for a complete rest"],
#    'context_set': ''},
#   {'tag': '998',
#    'patterns': ["there's nothing like weightless sleep for a complete rest"],
#    'responses': ['when do we arrive at clavius'],
#    'context_set': ''},
#   {'tag': '999',
#    'patterns': ['when do we arrive at clavius'],
#    'responses': ['we are scheduled to dock in about seven hours is there anything we can do for you'],
#    'context_set': ''},
#   ...]}

# %%
with open("intents.json", "w") as outfile:  
    json.dump(intents, outfile)
